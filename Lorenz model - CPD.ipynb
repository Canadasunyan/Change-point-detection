# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import time
import pickle
torch.set_num_threads(1)
import time
import numpy as np
import torch
import scipy
import argparse
import sys
import matplotlib.pyplot as plt
import matplotlib
from arma import ode_system, solve_magi
from arma import matrix
import time
import pickle
from multiprocessing import Pool
import scipy.special as fun
torch.set_default_dtype(torch.double)

class Bessel(torch.autograd.Function):
    @staticmethod
    def forward(ctx, inp, nu):
        ctx._nu = nu
        ctx.save_for_backward(inp)
        mat = fun.kv(nu, inp.detach().numpy())
        return (torch.from_numpy(np.array(mat)))

    @staticmethod
    def backward(ctx, grad_out):
        inp, = ctx.saved_tensors
        nu = ctx._nu
        grad_in = grad_out.numpy() * np.array(fun.kvp(nu, inp.detach().numpy()))
        return (torch.from_numpy(grad_in), None)


class generalMatern(object):

    # has_lengthscale = True

    def __init__(self, nu, lengthscale, **kwargs):
        # super(Matern,self).__init__(**kwargs)
        self.nu = nu
        self.log_lengthscale = torch.tensor(np.log(lengthscale))
        self.log_lengthscale.requires_grad_(True)

    def _set_lengthscale(self, lengthscale):
        self.log_lengthscale = torch.tensor(np.log(lengthscale))

    def lengthscale(self):
        return (torch.exp(self.log_lengthscale).item())

    def forward(self, x1, x2=None, **params):
        lengthscale = torch.exp(self.log_lengthscale)
        x1 = x1.squeeze()
        if x2 is None: x2 = x1
        r_ = (x1.reshape(-1, 1) - x2.reshape(1, -1)).abs()
        r_ = np.sqrt(2. * self.nu) * r_ / lengthscale
        # handle limit at 0, allows more efficient backprop
        r_ = torch.clamp(r_, min=1e-15)
        C_ = np.power(2, 1 - self.nu) * np.exp(-fun.loggamma(self.nu)) * torch.pow(r_, self.nu)
        mat = Bessel.apply(r_, self.nu)
        C_ = C_ * mat
        return (C_)

    def C(self, x1, x2=None):
        return (self.forward(x1, x2).detach())


def GPTrain(train_x, train_y, nu, lengthscale_lb=3., learning_rate=1e-6, noisy=True, max_iter=5, verbose=False,
            eps=1e-6):
    # preprocess input data
    n = train_x.size(0)
    # normalized x to 0 and 1
    x_range = [torch.min(train_x).item(), torch.max(train_x).item()]
    train_x = (train_x - x_range[0]) / (x_range[1] - x_range[0])
    #     train_x[0] = eps
    # set up kernel
    kernel = generalMatern(nu=nu, lengthscale=1.1 * lengthscale_lb / (x_range[1] - x_range[0]))
    # lambda = noise/outputscale
    log_lambda = torch.tensor(np.log(1e-2))
    log_lambda.requires_grad_(True)
    loglb_normalized = torch.log(torch.tensor(lengthscale_lb / (x_range[1] - x_range[0])))
    optimizer = torch.optim.LBFGS([kernel.log_lengthscale, log_lambda], lr=learning_rate)
    # training
    prev_loss = np.Inf
    for i in range(max_iter):
        R = kernel.forward(train_x) + torch.exp(log_lambda) * torch.eye(n)
        e, v = torch.eig(R, eigenvectors=True)
        e = e[:, 0]  # eigenvalues
        a = v.T @ torch.ones(n)
        b = v.T @ train_y
        mean = ((a / e).T @ b) / ((a / e).T @ a)
        d = v.T @ (train_y - mean)
        outputscale = 1. / n * (d / e).T @ d

        def closure():
            optimizer.zero_grad()
            R = kernel.forward(train_x) + torch.exp(log_lambda) * torch.eye(n)
            e, v = torch.eig(R, eigenvectors=True)
            e = e[:, 0]  # eigenvalues
            a = v.T @ torch.ones(n)
            b = v.T @ train_y
            mean = ((a / e).T @ b) / ((a / e).T @ a)
            d = v.T @ (train_y - mean)
            outputscale = 1. / n * (d / e).T @ d
            loss = torch.log(outputscale) + torch.mean(torch.log(e))
            tmp0 = torch.clamp(kernel.log_lengthscale, max=0.)
            loss = loss + 1e3 * torch.sum(torch.square(kernel.log_lengthscale - tmp0))
            tmp = torch.clamp(kernel.log_lengthscale, min=loglb_normalized)
            loss = loss + 1e3 * torch.sum(torch.square(kernel.log_lengthscale - tmp))
            tmp2 = torch.clamp(log_lambda, min=np.log(1e-6))
            loss = loss + 1e3 * torch.sum(torch.square(log_lambda - tmp2))
            loss.backward()
            return loss

        optimizer.step(closure)

    R = kernel.forward(train_x) + torch.exp(log_lambda) * torch.eye(n)
    Rinv = torch.inverse(R)
    ones = torch.ones(n)
    mean = ((ones.T @ Rinv @ train_y) / (ones.T @ Rinv @ ones)).item()
    outputscale = (1 / n * (train_y - mean).T @ Rinv @ (train_y - mean)).item()
    noisescale = outputscale * torch.exp(log_lambda).item()
    return outputscale



def fOde(theta, x):
    """
    description of ODE
    theta: list[3]: [k1, k_{-1}, k2]
    return: array(n, 4)
    """
    xs = x[:, 0]
    ys = x[:, 1]
    zs = x[:, 2]
    xdt = theta[0] * (ys-xs)
    ydt = xs * (theta[1] - zs) - ys
    zdt = xs * ys - theta[2] * zs
    return np.stack([xdt, ydt, zdt], axis=1)

def fOdeDx(theta, x):
    """
    returns ODE derivation of x given theta
    theta: list[3]
    x: array(n, 4)
    return: array(n, 3, 3)
    """
    xs = x[:, 0]
    ys = x[:, 1]
    zs = x[:, 2]
    resultDx = np.zeros(shape=[np.shape(x)[0], 3, 3])
    # [:, i, j]: jth equation derivative of the ith state
    # (0) / dx
    resultDx[:, 0, 0] = -theta[0]
    # (0) / dy
    resultDx[:, 1, 0] =  theta[0]
    # (1) / dx
    resultDx[:, 0, 1] = theta[1] - zs
    # (1) / dy
    resultDx[:, 1, 1] = -1.
    # (1) / dz
    resultDx[:, 2, 1] = -xs
    # (2) / dx
    resultDx[:, 0, 2] = ys
    # (2) / dy
    resultDx[:, 1, 2] = xs
    # (2) / dz
    resultDx[:, 2, 2] = -theta[2]
    return resultDx

def fOdeDtheta(theta, x):
    """
    returns ODE derivation of theta given x
    theta: list[3]
    x: array(n, 4)
    return: array(n, 3, 4)
    """
    resultDtheta = np.zeros(shape=[np.shape(x)[0], 3, 3])
    # [:, i, j]: jth equation derivative of the ith theta
    xs = x[:, 0]
    ys = x[:, 1]
    zs = x[:, 2]
    # (0) / dsigma
    resultDtheta[:, 0, 0] = ys - xs
    # (1) / drho
    resultDtheta[:, 1, 1] = xs
    # (2) / dbeta
    resultDtheta[:, 2, 2] = -zs
    return resultDtheta

def copy_mat(arma_mat):
    return np.copy(matrix(arma_mat).reshape([-1])).reshape([arma_mat.n_rows, arma_mat.n_cols])


# Construct theta series
def calibration_construct(vals, occurence_times_2):
    ls = []
    for idx in range(len(occurence_times_2)):
        for repeat_num in range(occurence_times_2[idx]):
            ls.append(vals[idx])
    return torch.cat(ls, axis=0)


def fOdeTorch(theta, x, constant_param_ls):
    """
    theta: list[4]: beta, ve, vi, pd
    x: array(n, 4)
    r: array(n, 2)
    """
    xs = x[:, 0]
    ys = x[:, 1]
    zs = x[:, 2]
    xdt = constant_param_ls[0] * (ys-xs)
    ydt = xs * (theta[:, 0] - zs) - ys
    zdt = xs * ys - constant_param_ls[1] * zs
    return torch.stack([xdt, ydt, zdt], axis=1)



def pointwisethetasigmallikTorch(xlatent, theta, time_constant_param_ls, sigma, ydata, CovAllDimensionsPyList, fOdeTorch,
                                     priorTemperature, bound=None):
    # length of observed y (t)
    n = ydata.shape[0]
    pdimension = ydata.shape[1]
    thetadimension = theta.shape[1]
    sigmaSq = torch.pow(sigma, 2)
    fderiv = fOdeTorch(theta, xlatent, time_constant_param_ls)
    res = torch.zeros([pdimension, 3]).double()
    fitDerivError = torch.zeros([n, pdimension]).double()
    nobs = torch.zeros([pdimension]).double()
    fitLevelErrorSumSq = torch.zeros([pdimension]).double()
    for vEachDim in range(pdimension):
        fitDerivError[:, vEachDim] = fderiv[:, vEachDim]
        fitDerivError[:, vEachDim] -= CovAllDimensionsPyList[vEachDim]['mphi'] @ xlatent[:, vEachDim]
        nobs[vEachDim] = torch.sum(torch.isfinite(ydata[:, vEachDim]))
        obsIdx = torch.isfinite(ydata[:, vEachDim])
        fitLevelErrorSumSq[vEachDim] = torch.sum(torch.square(xlatent[obsIdx, vEachDim] - ydata[obsIdx, vEachDim]))
    res[:, 0] = -0.5 * fitLevelErrorSumSq / sigmaSq - torch.log(sigma + 0.001) * nobs
    res[:, 0] /= priorTemperature[0][2]
    KinvfitDerivError = torch.zeros([n, pdimension]).double()
    CinvX = torch.zeros([n, pdimension]).double()
    for vEachDim in range(pdimension):
        # inverse of K
        KinvfitDerivError[:, vEachDim] = CovAllDimensionsPyList[vEachDim]['Kinv'] @ fitDerivError[:, vEachDim]
        # inverse of Cd
        CinvX[:, vEachDim] = CovAllDimensionsPyList[vEachDim]['Cinv'] @ xlatent[:, vEachDim]
    res[:, 1] = -0.5 * torch.sum(fitDerivError * KinvfitDerivError, dim=0) / priorTemperature[0][0]
    #  prior distriobution of X-
    res[:, 2] = -0.5 * torch.sum(xlatent * CinvX, dim=0)
    for i in range(pdimension):
        res[i, 2] /= priorTemperature[i][1]
    if bound:
        extra_loss = torch.tensor([0.])
        for i in range(len(time_constant_param_ls)):
            extra_loss -= 1e20 * torch.square(time_constant_param_ls[i]-torch.clamp(time_constant_param_ls[i], min=bound[i].item() - 0.0001))
            extra_loss -= 1e20 * torch.square(time_constant_param_ls[i]-torch.clamp(time_constant_param_ls[i], max=bound[i].item() + 0.0001))
        return torch.sum(res) + torch.sum(extra_loss), res.detach().numpy()
    return torch.sum(res), res.detach().numpy()


def construct_kernel(dimension, covAllDimensions):
    PyList = []
    for each_gpcov in covAllDimensions:
        p_K = np.array(each_gpcov.mphi) @ np.array(each_gpcov.C)
        K_pp = np.array(each_gpcov.Kphi) - p_K @ np.array(each_gpcov.Cinv) @ p_K
        Cinv_tmp = np.linalg.pinv(np.array(each_gpcov.C)[:dimension, :dimension], hermitian=True)
        mphi_tmp = p_K[:dimension, :dimension] @ Cinv_tmp
        K_tmp = K_pp[:dimension, :dimension] + p_K[:dimension, :dimension] @ Cinv_tmp @ p_K[:dimension, :dimension]
        Kinv_tmp = np.linalg.pinv(K_tmp, hermitian=True)
        each_pycov = dict(
        Cinv=torch.tensor(Cinv_tmp),
        Kinv=torch.tensor(Kinv_tmp),
        mphi=torch.tensor(mphi_tmp),
    )
        PyList.append(each_pycov)
    return PyList




rho = np.concatenate((28 * np.ones(1200000), 30 * np.ones(200000), 28 * np.ones(400000), 30 * np.ones(200000)))

def gen_data(rho, sigma=10, beta=2.667, initial_states=[0., 1., 1.05], obs_per_day=40, days=50, noise=0.5, linspace=1000):
    nobs = days
    step_size = 1. / (linspace * obs_per_day)
    state_ls = np.ones((days * linspace * obs_per_day, 3))
    state_ls[0] = initial_states.copy()
    for i in range(1, linspace * days * obs_per_day):
        index = i - 1
        state_ls[i][0] = state_ls[i - 1][0] + step_size * (sigma * (state_ls[i - 1][1] - state_ls[i - 1][0]))
        state_ls[i][1] = state_ls[i - 1][1] + step_size * (state_ls[i - 1][0] * (rho[index]-state_ls[i - 1][2]) - state_ls[i - 1][1])
        state_ls[i][2] = state_ls[i - 1][2] + step_size * (state_ls[i - 1][0] * state_ls[i - 1][1] - beta * state_ls[i - 1][2])
#         print(state_ls[i])
    states = state_ls[::linspace]
    states += np.random.normal(0, noise, states.shape)
    return states

yobs_np = gen_data(rho)[1000:]
plt.plot(yobs_np)
# Out:
# [<matplotlib.lines.Line2D at 0x7f2070777f60>,
#  <matplotlib.lines.Line2D at 0x7f2070786a58>,
#  <matplotlib.lines.Line2D at 0x7f2070786b38>]

# %%
rho0 = rho[::1000][1000:]
plt.plot(rho0)

# %%
max_kernel_size = 40
discretization = 1
obs_per_day = 40 
days = 1
theta_lowerbound=np.array([0., 0., 0.])
theta_upperbound=np.array([np.inf, np.inf, np.inf])
param_names = ['sigma', 'rho', 'beta']
is_time_varying=[False, True, False] 
use_trajectory='inferred'
learning_rate=np.array([1e-4, 1e-3, 1e-5])
n_iter = [15001, 200000, 15000, 200000]

yobs = yobs_np[:40]
start_time = time.time()
nobs, p_dim = yobs.shape[0], yobs.shape[1]
n_points = nobs * discretization
theta_dim = theta_lowerbound.shape[0]
d_matrix = torch.zeros((n_points, n_points), dtype=torch.double)
for i in range(n_points):
    for j in range(n_points):
        if i > j:
            d_matrix[i][j] = (i - j) / (obs_per_day * discretization)
        else:
            d_matrix[i][j] = (j - i) / (obs_per_day * discretization)
Ode_system = ode_system("ODE-python", fOde, fOdeDx, fOdeDtheta,
                         thetaLowerBound=theta_lowerbound,
                         thetaUpperBound=theta_upperbound)
tvecObs = np.arange(0, days, 1. / obs_per_day)
tvecFull = np.arange(0, days, 1. / (obs_per_day * discretization))
yFull = np.ndarray([n_points, p_dim])
yFull.fill(np.nan)
yFull[np.arange(0, discretization * nobs, discretization).astype(int), :] = yobs
xInitExogenous = np.zeros_like(yFull)
# interpolate: find the ydata of tvecFull given observations
for i in range(p_dim):
    xInitExogenous[:, i] = np.interp(tvecFull, tvecObs, yobs[:, i])
# First stage: use MAGI package to optimize theta as constant
result = solve_magi(
    yFull,
    Ode_system,
    tvecFull,
    sigmaExogenous=np.array([]),
    phiExogenous=np.array([[]]),
    xInitExogenous=xInitExogenous,
    thetaInitExogenous=np.array([]),
    muExogenous=np.array([[]]),
    dotmuExogenous=np.array([[]]),
    priorTemperatureLevel=yFull.shape[0] / yobs.shape[0],
    priorTemperatureDeriv=yFull.shape[0] / yobs.shape[0],
    priorTemperatureObs=1.0,
    kernel="generalMatern",
    nstepsHmc=400,
    burninRatioHmc=0.5,
    niterHmc=n_iter[0],
    stepSizeFactorHmc=0.01,
    nEpoch=1,
    bandSize=40,
    useFrequencyBasedPrior=True,
    useBand=False,
    useMean=False,
    useScalerSigma=False,
    useFixedSigma=False,
    verbose=True)
samplesCpp = result['samplesCpp']
llikId = 0
xId = range(np.max(llikId) + 1, np.max(llikId) + yFull.size + 1)
# dimension of theta
thetaId = range(np.max(xId) + 1, np.max(xId) + theta_dim + 1)
sigmaId = range(np.max(thetaId) + 1, np.max(thetaId) + yFull.shape[1] + 1)
burnin = int(n_iter[0] * 0.5)
xsampled = samplesCpp[xId, (burnin + 1):]
xsampled = xsampled.reshape([yFull.shape[1], yFull.shape[0], -1])
CovAllDimensionsPyList = []
thetaSampled = samplesCpp[thetaId, (burnin + 1):]
inferred_theta = np.mean(thetaSampled, axis=-1)
sigmaSampled = samplesCpp[sigmaId, (burnin + 1):]
inferred_sigma = np.mean(sigmaSampled, axis=-1)
inferred_trajectory = np.mean(xsampled, axis=-1)
for each_gpcov in result['result_solved'].covAllDimensions:
    each_pycov = dict(
        Cinv=torch.from_numpy(matrix(each_gpcov.Cinv)).double(),
        Kinv=torch.from_numpy(matrix(each_gpcov.Kinv)).double(),
        mphi=torch.from_numpy(matrix(each_gpcov.mphi)).double(),
    )
    CovAllDimensionsPyList.append(each_pycov)
    
inferred_theta
# Out:
# array([ 9.74387336, 28.15175228,  2.6899071 ])

# %%
100 9.87089664, 28.08106219,  2.65037194
200 9.73692355, 28.15088785,  2.68968972])
[ 9.74387336, 28.15175228,  2.6899071 ]

# %%
batch_size = 1
n_batch = 900
regret_length = 5
torch.set_default_dtype(torch.double)     
is_time_varying=[False, True, False] 
result_ls = []
cpd_ls = []
latentx_ls = []
h0_x_ls= []
h1_x_ls= []
psi_ls = []
indicator_ls = []
history_value = torch.tensor(inferred_theta[1] * torch.ones(days * obs_per_day)).reshape(-1, 1)
history_indicator = np.zeros(len(history_value))
init_scale = np.zeros(yobs_np.shape[1])
for EachDim in range(yobs_np.shape[1]):
    initial_scale = GPTrain(torch.tensor(np.linspace(0., 1., 40)),torch.tensor(yobs_np[:40])[:, EachDim], 2.01)
    print(initial_scale)
    init_scale[EachDim] = initial_scale            
sigma_torch = torch.tensor(inferred_sigma, dtype=torch.double)
time_constant_param_ls = [] # List[tensor[1], tensor[1], tensor[1], tensor[1]]
for thetaEachDim in range(theta_dim):
    if is_time_varying[thetaEachDim] == False:
        param_name = param_names[thetaEachDim]
        globals()[param_name] = torch.tensor([inferred_theta[thetaEachDim]], requires_grad=True, dtype=torch.double) # , requires_grad=True
        time_constant_param_ls.append(eval(param_name))
# for each new batch
# new coming data: (EachBatch+1) * batch_size + days * obs_per_day)+regret_length
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   del sys.path[0]
# 1949.958185592463
# 3679.0139207069446
# 6678.718868476316

# %%
kernel_size = 40
regret_length = 10
skip = 0
for EachBatch in range(n_batch):
    print('Batch ' + str(EachBatch))
    if skip:
        skip -= 1
        result_ls.append('*')
        history_indicator = np.concatenate([history_indicator[1:], np.array([history_indicator[-1]])])
        history_value = torch.cat((history_value[1:], history_value[-1].reshape(1, -1)))
        continue
        
    previous_psi = []
    for each in time_constant_param_ls:
        previous_psi.append(each.detach().clone())
    print(previous_psi)
    start_idx = int(EachBatch * batch_size)+regret_length
    end_idx = int(EachBatch * batch_size + days * obs_per_day)+regret_length
    print(rho0[end_idx])
    # each time update one step
    history_indicator = np.concatenate([history_indicator[1:], np.array([history_indicator[-1]])])
    history_value = torch.cat((history_value[1:], history_value[-1].reshape(1, -1)))
    if kernel_size < 40:
        # update kernel
        print('kernel_size: ', kernel_size)
        yobs = yobs_np[end_idx - kernel_size:end_idx]
        tmp_CovAllDimensionsPyList = construct_kernel(kernel_size, result['result_solved'].covAllDimensions)
        window_scale = np.zeros(yobs.shape[1])
        for EachDim in range(yobs.shape[1]):
            scale = GPTrain(torch.tensor(np.linspace(1./40, kernel_size/40, kernel_size)),torch.tensor(yobs)[:, EachDim], 2.01)
            window_scale[EachDim] = scale
        ydata = torch.from_numpy(yobs).double()
        priorTemperature = torch.tensor([[1, max(window_scale[0] / init_scale[0], 0.1), 1], 
                                         [1, max(window_scale[1] / init_scale[1], 0.1), 1],
                                         [1, max(window_scale[1] / init_scale[2], 0.1), 1]])
        print('Temperature: ', priorTemperature)
        cur_loss = np.inf
        tmp_occurence_times = np.array([kernel_size-regret_length, regret_length])
        new_construct_vals = [torch.tensor([[rho0[end_idx - kernel_size]]], requires_grad=True)] + [torch.tensor([[rho0[end_idx]]], requires_grad=True)]
        # new_construct_vals = [torch.tensor([EachSplit[0]], requires_grad=True) for EachSplit in splits] + [torch.tensor([history_value[-1].numpy()], requires_grad=True)]    
        print('new_construct_vals: ', new_construct_vals)
        
        print('tmp_occurence_times: ', tmp_occurence_times)
        lik_ls = np.zeros(min(kernel_size, regret_length)+1)
        theta_ls = []
        truncate_pointwise_xlatent_torch_tmp = torch.tensor(ydata, requires_grad=True, dtype=torch.double)
        # try every time stamp
        for EachIter in range(min(kernel_size, regret_length) +1):
            # if change point exists in the last 12 observations, label as no 
            print(EachIter, tmp_occurence_times)
            pointwise_optimizer = torch.optim.Adam([truncate_pointwise_xlatent_torch_tmp]+ new_construct_vals, lr=1e-4)  #  , weight_decay = 1.0
            pointwise_lr_scheduler = torch.optim.lr_scheduler.StepLR(pointwise_optimizer, step_size=5000, gamma=0.5)
            cur_loss_tmp = np.inf
            for epoch in range(100000):
                pointwise_optimizer.zero_grad()
                # compute loss function
                new_theta = calibration_construct(new_construct_vals, tmp_occurence_times)
                llik, res = pointwisethetasigmallikTorch(truncate_pointwise_xlatent_torch_tmp, new_theta, time_constant_param_ls, sigma_torch, 
                                             ydata, tmp_CovAllDimensionsPyList, fOdeTorch, priorTemperature, previous_psi)
                new_loss = -llik
                if epoch % 1000 == 0:
#                         print(epoch, new_loss.item())
                    diff = new_loss.item() - cur_loss_tmp
                    if torch.isnan(new_loss) == False and diff > -0.01 and diff < 0.01:
                        break
                    cur_loss_tmp = new_loss.item()
                new_loss.backward()
                pointwise_optimizer.step()
                pointwise_lr_scheduler.step()
            lik_ls[EachIter] = llik.item()
            theta_ls.append(new_theta.detach().clone())
            print(res)
            print(new_construct_vals)
            tmp_occurence_times[-2] += 1
            tmp_occurence_times[-1] -= 1
        lik_ls = np.flip(lik_ls)
        theta_ls.reverse()
        print(lik_ls)
        print('time_constant_param_ls', time_constant_param_ls)
        # update history of gamma
        # change point not detected
        if max(lik_ls) - lik_ls[0] <= 50.:
            # update history
            print('No change point!')
            last_val_tmp = theta_ls[np.argmax(lik_ls)][-1].item()
            result_ls.append(theta_ls[0].clone())
            val_defined = True
    #         print('accepted_theta: ', accepted_theta)
            kernel_size += 1
        else:
            last_val_tmp = theta_ls[np.argmax(lik_ls)][-1].item()
            result_ls.append(theta_ls[np.argmax(lik_ls)].clone())
            idx = np.argmax(lik_ls)
            print('Change point: CPD alarm! ', end_idx - idx)
            cpd_ls.append(end_idx - idx)
            kernel_size = 12
        continue

    print('Final kernel size: ', kernel_size)
    # y[12:72]
    yobs = yobs_np[end_idx-kernel_size:end_idx]
    window_scale = np.zeros(yobs.shape[1])
    for EachDim in range(yobs.shape[1]):
        scale = GPTrain(torch.tensor(np.linspace(0., 1., 40)),torch.tensor(yobs)[:, EachDim], 2.01)
        window_scale[EachDim] = scale
    ydata = torch.from_numpy(yobs).double()
    priorTemperature = torch.tensor([[1, max(window_scale[0] / init_scale[0], 0.01), 1], 
                                     [1, max(window_scale[1] / init_scale[1], 0.01), 1],
                                     [1, max(window_scale[1] / init_scale[2], 0.01), 1]])
    print('Temperature: ', priorTemperature)
    cur_loss = np.inf
    occurence_times = np.array([regret_length, 0])
    tmp_history_indicator = history_indicator[:days * obs_per_day-regret_length]
    splits = np.split(history_value[:days * obs_per_day-regret_length].numpy(),np.where(np.diff(tmp_history_indicator))[0]+1)
#     print('Initial splits: ', splits)
    tmp = [len(i) for i in splits]
    tmp_occurence_times = np.array(tmp + [regret_length])
    new_construct_vals = [torch.tensor([EachSplit[0]], requires_grad=True) for EachSplit in splits] + [torch.tensor([history_value[-1].numpy()], requires_grad=True)]
    print('new_construct_vals: ', new_construct_vals)
    print('tmp_occurence_times: ', tmp_occurence_times)
    lik_ls = np.zeros(regret_length+1)
    theta_ls = []
    truncate_pointwise_xlatent_torch_tmp = torch.tensor(ydata, requires_grad=True, dtype=torch.double)
    # try every time stamp
    for EachIter in range(regret_length+1):
        # if change point exists in the last 12 observations, label as no 
        print(EachIter, tmp_occurence_times)
        pointwise_optimizer = torch.optim.Adam([truncate_pointwise_xlatent_torch_tmp]+ new_construct_vals + time_constant_param_ls, lr=1e-4)  #  , weight_decay = 1.0
        pointwise_lr_scheduler = torch.optim.lr_scheduler.StepLR(pointwise_optimizer, step_size=5000, gamma=0.5)
        cur_loss_tmp = np.inf
        for epoch in range(100000):
            pointwise_optimizer.zero_grad()
            # compute loss function
            new_theta = calibration_construct(new_construct_vals, tmp_occurence_times)
            llik, res = pointwisethetasigmallikTorch(truncate_pointwise_xlatent_torch_tmp, new_theta, time_constant_param_ls, sigma_torch, 
                                         ydata, CovAllDimensionsPyList, fOdeTorch, priorTemperature, previous_psi)
            new_loss = -llik
            if epoch % 1000 == 0:
#                 print(epoch, new_loss.item())
                diff = new_loss.item() - cur_loss_tmp
                if torch.isnan(new_loss) == False and diff > -0.01 and diff < 0.01:
                    break
                cur_loss_tmp = new_loss.item()
            new_loss.backward()
            pointwise_optimizer.step()
            pointwise_lr_scheduler.step()
        lik_ls[EachIter] = llik.item()
        theta_ls.append(new_theta.detach())
        print(res)
        print('final construct vals: ', new_construct_vals)
        tmp_occurence_times[-2] += 1
        tmp_occurence_times[-1] -= 1

    lik_ls = np.flip(lik_ls)
    theta_ls.reverse()
    print(lik_ls)
    print('time_constant_param_ls', time_constant_param_ls)
    # update history of gamma
    # change point not detected
    if max(lik_ls) - lik_ls[0] <= 50.:
        # update history
        print('No change point!')
        accepted_theta = theta_ls[0].detach().clone() # size: tensor([96])
        accepted_theta_np = accepted_theta.numpy() # size: tensor([96])
#         print('accepted_theta: ', accepted_theta)
        for i in range(1, days * obs_per_day):
            if np.sum(np.abs(accepted_theta_np[i] - accepted_theta_np[i-1])) < 1e-3:
                history_indicator[i] = history_indicator[i-1]
            else:
                history_indicator[i] = 1 - history_indicator[i-1]   
        history_value = accepted_theta.clone()
#         print('history value: ', history_value)
        result_ls.append(history_value)
        indicator_ls.append(history_indicator)
        latentx_ls.append(truncate_pointwise_xlatent_torch_tmp)


    # change point detected
    else:     
        idx = np.argmax(lik_ls)
        print('Change point: ', end_idx-idx)
        cpd_ls.append(end_idx-idx)
        # update history
        accepted_theta = theta_ls[np.argmax(lik_ls)].detach().clone()
        accepted_theta_np = accepted_theta.numpy()
#         print('accepted_theta: ', accepted_theta)
        for i in range(1, days * obs_per_day):
            if np.sum(np.abs(accepted_theta_np[i] - accepted_theta_np[i-1])) < 1e-3:
                history_indicator[i] = history_indicator[i-1]
            else:
                history_indicator[i] = 1 - history_indicator[i-1]   
        history_value = accepted_theta.detach()
        indicator_ls.append(history_indicator)
        result_ls.append(history_value)
        latentx_ls.append(truncate_pointwise_xlatent_torch_tmp)
        psi_to_save = []
        for EachPsi in time_constant_param_ls:
            psi_to_save.append(EachPsi.detach().clone())
        psi_ls.append(psi_to_save)
        kernel_size = 12
        skip = 20

pickle.dump(cpd_ls, open('Lorenz-change-point-'+ str(random_idx) + '.pkl', "wb" ))
pickle.dump(result_ls, open('Lorenz-new-result-'+ str(random_idx) + '.pkl', "wb" ))


# if __name__ ==  '__main__': 
#     torch.set_num_threads(1)
#     pool = Pool(processes=100)
#     results = pool.map(main_func, range(1))
#     pool.close()
#     pool.join()
# Out:
# Batch 0
# [tensor([9.8709]), tensor([2.6504])]
# 28.0
# Final kernel size:  40
# Temperature:  tensor([[1.0000, 0.9721, 1.0000],
#         [1.0000, 0.8878, 1.0000],
#         [1.0000, 0.4890, 1.0000]])
# new_construct_vals:  [tensor([[28.0811]], requires_grad=True), tensor([[28.0811]], requires_grad=True)]
# tmp_occurence_times:  [30 10]
# 0 [30 10]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:123: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# [[  3.70358331  -5.99406827  -8.48632727]
#  [  9.04574311  -6.38128432 -15.94357468]
#  [ 14.85981254  -2.05742471 -16.80743298]]
# final construct vals:  [tensor([[28.0904]], requires_grad=True), tensor([[28.1485]], requires_grad=True)]
# 1 [31  9]
# [[  2.8791486   -0.63076939  -7.35790239]
#  [  8.72742011  -1.26820073 -12.99774932]
#  [ 14.20243721  -1.55043101 -16.14939221]]
# final construct vals:  [tensor([[28.0618]], requires_grad=True), tensor([[28.0798]], requires_grad=True)]
# 2 [32  8]
# [[  2.89173727  -0.62701968  -7.35627793]
#  [  8.72294982  -1.27229612 -12.99571914]
#  [ 14.19947988  -1.56183488 -16.14685219]]
# final construct vals:  [tensor([[28.0645]], requires_grad=True), tensor([[28.0697]], requires_grad=True)]
# 3 [33  7]
# [[  2.91065122  -0.6257047   -7.35425943]
#  [  8.72182489  -1.28030934 -12.9958772 ]
#  [ 14.20675015  -1.58395644 -16.14260219]]
# final construct vals:  [tensor([[28.0707]], requires_grad=True), tensor([[28.0431]], requires_grad=True)]
# 4 [34  6]
# [[  2.9335339   -0.62020465  -7.34970355]
#  [  8.75017585  -1.28936348 -12.99956775]
#  [ 14.21591888  -1.62571067 -16.1318027 ]]
# final construct vals:  [tensor([[28.0821]], requires_grad=True), tensor([[27.9819]], requires_grad=True)]
# 5 [35  5]
# [[  2.931408    -0.61497138  -7.34673943]
#  [  8.76857823  -1.29590126 -12.99302985]
#  [ 14.21992647  -1.63801979 -16.12439541]]
# final construct vals:  [tensor([[28.0864]], requires_grad=True), tensor([[27.9364]], requires_grad=True)]
# 6 [36  4]
# [[  2.92711932  -0.60855158  -7.34436785]
#  [  8.80142226  -1.28165453 -13.01238037]
#  [ 14.22008658  -1.64421243 -16.11293816]]
# final construct vals:  [tensor([[28.0903]], requires_grad=True), tensor([[27.8606]], requires_grad=True)]
# 7 [37  3]
# [[  2.9071278   -0.60549891  -7.3431145 ]
#  [  8.84959977  -1.30091872 -13.00607558]
#  [ 14.21258683  -1.63565396 -16.10533338]]
# final construct vals:  [tensor([[28.0895]], requires_grad=True), tensor([[27.7617]], requires_grad=True)]
# 8 [38  2]
# [[  2.87866655  -0.61005144  -7.34839617]
#  [  8.95302012  -1.22642913 -13.13555011]
#  [ 14.20992618  -1.60680533 -16.11535297]]
# final construct vals:  [tensor([[28.0839]], requires_grad=True), tensor([[27.6424]], requires_grad=True)]
# 9 [39  1]
# [[  2.9007824   -0.62896085  -7.35514366]
#  [  8.70956252  -1.26820174 -12.98515849]
#  [ 14.19223676  -1.56182042 -16.14416694]]
# final construct vals:  [tensor([[28.0622]], requires_grad=True), tensor([[28.0971]], requires_grad=True)]
# 10 [40  0]
# [[  2.89547518  -0.6269595   -7.35598951]
#  [  8.72194453  -1.27375182 -12.9958128 ]
#  [ 14.2008461   -1.56551895 -16.14623988]]
# final construct vals:  [tensor([[28.0656]], requires_grad=True), tensor([[28.0971]], requires_grad=True)]
# [-14.14600664 -14.14087043 -14.0009723  -14.02728068 -14.05547677
#  -14.09314442 -14.11672415 -14.14348305 -14.14583297 -14.14543914
#  -28.06097327]
# time_constant_param_ls [tensor([9.8710], requires_grad=True), tensor([2.6503], requires_grad=True)]
# No change point!
# Batch 1
# [tensor([9.8710]), tensor([2.6503])]
# 28.0
# Final kernel size:  40
# Temperature:  tensor([[1.0000, 0.9381, 1.0000],
#         [1.0000, 0.8316, 1.0000],
#         [1.0000, 0.4581, 1.0000]])
# new_construct_vals:  [tensor([[28.0656]], requires_grad=True), tensor([[28.0656]], requires_grad=True)]
# tmp_occurence_times:  [30 10]
# 0 [30 10]
# [[  2.84087471  -5.90723291  -8.77285389]
#  [  9.12550963  -6.41692245 -17.36223644]
#  [ 14.92219761  -1.98365649 -17.97273644]]
# final construct vals:  [tensor([[28.0845]], requires_grad=True), tensor([[28.2845]], requires_grad=True)]
# 1 [31  9]
# [[  2.14382643  -0.59191342  -7.63707209]
#  [  8.74089672  -1.41470672 -14.26704449]
#  [ 14.2185832   -1.47561951 -17.24928377]]
# final construct vals:  [tensor([[28.0595]], requires_grad=True), tensor([[28.1688]], requires_grad=True)]
# 2 [32  8]
# [[  2.16362157  -0.59010567  -7.63597021]
#  [  8.72215635  -1.4236449  -14.26732299]
#  [ 14.22501621  -1.49485677 -17.24867863]]
# final construct vals:  [tensor([[28.0655]], requires_grad=True), tensor([[28.1574]], requires_grad=True)]
# 3 [33  7]
# [[  2.17695849  -0.58824614  -7.63494741]
#  [  8.70567543  -1.43631659 -14.26779304]
#  [ 14.24232316  -1.52568476 -17.24784045]]
# final construct vals:  [tensor([[28.0757]], requires_grad=True), tensor([[28.1303]], requires_grad=True)]
# 4 [34  6]
# [[  2.18254542  -0.58792152  -7.6347426 ]
#  [  8.70708518  -1.4381138  -14.27095513]
#  [ 14.24585423  -1.53674538 -17.24766502]]
# final construct vals:  [tensor([[28.0789]], requires_grad=True), tensor([[28.1247]], requires_grad=True)]
# 5 [35  5]
# [[  2.18445736  -0.58717085  -7.6342431 ]
#  [  8.70871534  -1.44287273 -14.26858307]
#  [ 14.24940151  -1.54582535 -17.24759935]]
# final construct vals:  [tensor([[28.0815]], requires_grad=True), tensor([[28.1207]], requires_grad=True)]
# 6 [36  4]
# [[  2.1935617   -0.58861488  -7.63418492]
#  [  8.70239377  -1.44231685 -14.26539411]
#  [ 14.24729538  -1.54471535 -17.24874432]]
# final construct vals:  [tensor([[28.0804]], requires_grad=True), tensor([[28.1406]], requires_grad=True)]
# 7 [37  3]
# [[  2.20764261  -0.58973571  -7.63314642]
#  [  8.68555137  -1.44409311 -14.2491606 ]
#  [ 14.24345547  -1.54517892 -17.24902978]]
# final construct vals:  [tensor([[28.0793]], requires_grad=True), tensor([[28.1855]], requires_grad=True)]
# 8 [38  2]
# [[  2.26921029  -0.59698733  -7.62761812]
#  [  8.68363749  -1.5007105  -14.05599008]
#  [ 14.20442165  -1.54339596 -17.24831738]]
# final construct vals:  [tensor([[28.0677]], requires_grad=True), tensor([[28.5542]], requires_grad=True)]
# 9 [39  1]
# [[  2.23384598  -0.5897505   -7.6272131 ]
#  [  8.85403336  -1.26907943 -13.96828242]
#  [ 14.20289786  -1.54790638 -17.23632943]]
# final construct vals:  [tensor([[28.0723]], requires_grad=True), tensor([[29.2264]], requires_grad=True)]
# 10 [40  0]
# [[  2.16915229  -0.58034947  -7.63486131]
#  [  8.72638812  -1.4458692  -14.27527942]
#  [ 14.26865104  -1.56749929 -17.24906336]]
# final construct vals:  [tensor([[28.0901]], requires_grad=True), tensor([[29.2264]], requires_grad=True)]
# [-17.58873061 -16.94778406 -17.41574993 -17.57369507 -17.58071959
#  -17.58372025 -17.58065862 -17.57587133 -17.54978502 -17.53233364
#  -31.52705668]
# time_constant_param_ls [tensor([9.8711], requires_grad=True), tensor([2.6502], requires_grad=True)]
# No change point!
# Batch 2
# [tensor([9.8711]), tensor([2.6502])]
# 28.0
# Final kernel size:  40
# Temperature:  tensor([[1.0000, 0.8967, 1.0000],
#         [1.0000, 0.7909, 1.0000],
#         [1.0000, 0.4357, 1.0000]])
# new_construct_vals:  [tensor([[28.0901]], requires_grad=True), tensor([[28.0901]], requires_grad=True)]
# tmp_occurence_times:  [30 10]
# 0 [30 10]
# [[  2.7644037   -5.89195405  -9.22488542]
#  [  9.72672105  -6.36118692 -18.7813578 ]
#  [ 14.79925775  -2.02413816 -18.92928206]]
# final construct vals:  [tensor([[28.0880]], requires_grad=True), tensor([[28.3650]], requires_grad=True)]
# 1 [31  9]
# [[  1.67098101  -0.5961876   -8.09382888]
#  [ 10.13678382  -1.21536635 -15.67594452]
#  [ 13.89600228  -1.39984803 -18.16403029]]
# final construct vals:  [tensor([[28.0898]], requires_grad=True), tensor([[28.2415]], requires_grad=True)]
# 2 [32  8]
# [[  1.69864265  -0.5916705   -8.09290706]
#  [ 10.11270989  -1.2336184  -15.67204343]
#  [ 13.89069949  -1.43131231 -18.16587036]]
# final construct vals:  [tensor([[28.1005]], requires_grad=True), tensor([[28.2253]], requires_grad=True)]
# 3 [33  7]
# [[  1.71677415  -0.59376516  -8.09282761]
#  [ 10.11081989  -1.2352059  -15.67858853]
#  [ 13.89121277  -1.44514624 -18.16702259]]
# final construct vals:  [tensor([[28.1037]], requires_grad=True), tensor([[28.2285]], requires_grad=True)]
# 4 [34  6]
# [[  1.72957145  -0.59512386  -8.09139352]
#  [ 10.10842588  -1.24737663 -15.66916906]
#  [ 13.89440065  -1.45965054 -18.16842726]]
# final construct vals:  [tensor([[28.1067]], requires_grad=True), tensor([[28.2368]], requires_grad=True)]
# 5 [35  5]
# [[  1.74538441  -0.59738879  -8.08932563]
#  [ 10.09674967  -1.24574183 -15.66535508]
#  [ 13.90173504  -1.46719496 -18.1679672 ]]
# final construct vals:  [tensor([[28.1075]], requires_grad=True), tensor([[28.2633]], requires_grad=True)]
# 6 [36  4]
# [[  1.75964795  -0.59721914  -8.08515949]
#  [ 10.07162847  -1.26173888 -15.62494836]
#  [ 13.90657902  -1.4790294  -18.1642656 ]]
# final construct vals:  [tensor([[28.1091]], requires_grad=True), tensor([[28.3103]], requires_grad=True)]
# 7 [37  3]
# [[  1.77111257  -0.60461748  -8.06997687]
#  [ 10.07983021  -1.24023195 -15.55605583]
#  [ 13.91038908  -1.48905037 -18.15121021]]
# final construct vals:  [tensor([[28.1037]], requires_grad=True), tensor([[28.4867]], requires_grad=True)]
# 8 [38  2]
# [[  1.75021583  -0.59845133  -8.05363657]
#  [ 10.11506063  -1.33123663 -15.31877197]
#  [ 13.88693764  -1.49147172 -18.14222886]]
# final construct vals:  [tensor([[28.1079]], requires_grad=True), tensor([[28.8174]], requires_grad=True)]
# 9 [39  1]
# [[  1.71993642  -0.57514077  -8.07250664]
#  [ 10.13093964  -1.20099037 -15.36030928]
#  [ 13.87561207  -1.52485335 -18.15877755]]
# final construct vals:  [tensor([[28.1248]], requires_grad=True), tensor([[29.1729]], requires_grad=True)]
# 10 [40  0]
# [[  1.70813093  -0.5727251   -8.09533234]
#  [ 10.19529134  -1.26714992 -15.68931628]
#  [ 13.8579338   -1.53202736 -18.17276537]]
# final construct vals:  [tensor([[28.1369]], requires_grad=True), tensor([[29.1729]], requires_grad=True)]
# [-19.5679603  -19.16608983 -19.18358299 -19.34981086 -19.47450543
#  -19.48910438 -19.4987429  -19.49374921 -19.48537002 -19.44143855
#  -33.92242192]
# time_constant_param_ls [tensor([9.8711], requires_grad=True), tensor([2.6501], requires_grad=True)]
# No change point!
# Batch 3
# [tensor([9.8711]), tensor([2.6501])]
# 28.0
# Final kernel size:  40
# Temperature:  tensor([[1.0000, 0.8271, 1.0000],
#         [1.0000, 0.7440, 1.0000],
#         [1.0000, 0.4098, 1.0000]])
# new_construct_vals:  [tensor([[28.1369]], requires_grad=True), tensor([[28.1369]], requires_grad=True)]
# tmp_occurence_times:  [30 10]
# 0 [30 10]
# [[  2.3638074   -5.99973514  -9.92414547]
#  [ 10.52200765  -6.60226401 -19.98148778]
#  [ 13.56463129  -2.07030212 -20.25072383]]
# final construct vals:  [tensor([[28.0934]], requires_grad=True), tensor([[28.2378]], requires_grad=True)]
# 1 [31  9]
# [[  2.20038415  -0.63330967  -8.80412584]
#  [ 10.29464326  -1.22658594 -16.634525  ]
#  [ 12.55790494  -1.27535341 -19.41243331]]
# final construct vals:  [tensor([[28.0927]], requires_grad=True), tensor([[28.1688]], requires_grad=True)]
# 2 [32  8]
# [[  2.20920195  -0.62968569  -8.80294906]
#  [ 10.29393178  -1.22815493 -16.63552697]
#  [ 12.55083741  -1.28291801 -19.41120114]]
# final construct vals:  [tensor([[28.0958]], requires_grad=True), tensor([[28.1683]], requires_grad=True)]
# 3 [33  7]
# [[  2.21918634  -0.63053411  -8.80182675]
#  [ 10.29435637  -1.23399187 -16.62989487]
#  [ 12.54744024  -1.2894791  -19.41133058]]
# final construct vals:  [tensor([[28.0969]], requires_grad=True), tensor([[28.1742]], requires_grad=True)]
# 4 [34  6]
# [[  2.23938134  -0.63330269  -8.79948014]
#  [ 10.29650018  -1.23245921 -16.62520969]
#  [ 12.53299571  -1.29275504 -19.40821186]]
# final construct vals:  [tensor([[28.0947]], requires_grad=True), tensor([[28.1951]], requires_grad=True)]
# 5 [35  5]
# [[  2.26648557  -0.63537121  -8.79433298]
#  [ 10.29659952  -1.2406839  -16.59497626]
#  [ 12.50658581  -1.29831215 -19.40097353]]
# final construct vals:  [tensor([[28.0917]], requires_grad=True), tensor([[28.2357]], requires_grad=True)]
# 6 [36  4]
# [[  2.31178267  -0.6418453   -8.77932585]
#  [ 10.36929006  -1.23144169 -16.53061374]
#  [ 12.42720587  -1.31146264 -19.37802765]]
# final construct vals:  [tensor([[28.0815]], requires_grad=True), tensor([[28.3574]], requires_grad=True)]
# 7 [37  3]
# [[  2.33106992  -0.64302871  -8.75553243]
#  [ 10.45857169  -1.23688051 -16.41163739]
#  [ 12.34973653  -1.3226392  -19.33980859]]
# final construct vals:  [tensor([[28.0790]], requires_grad=True), tensor([[28.5925]], requires_grad=True)]
# 8 [38  2]
# [[  2.29860635  -0.61282901  -8.75350819]
#  [ 10.44439898  -1.29158881 -16.28589322]
#  [ 12.42118402  -1.30600932 -19.34901105]]
# final construct vals:  [tensor([[28.0897]], requires_grad=True), tensor([[28.9414]], requires_grad=True)]
# 9 [39  1]
# [[  2.21567772  -0.60440187  -8.78815479]
#  [ 10.43503014  -1.22723009 -16.52778596]
#  [ 12.53738139  -1.29752463 -19.37931417]]
# final construct vals:  [tensor([[28.1105]], requires_grad=True), tensor([[29.2049]], requires_grad=True)]
# 10 [40  0]
# [[  2.17583519  -0.6144363   -8.80627054]
#  [ 10.30306601  -1.23974191 -16.64381331]
#  [ 12.59022147  -1.31150558 -19.42095654]]
# final construct vals:  [tensor([[28.1194]], requires_grad=True), tensor([[29.2049]], requires_grad=True)]
# [-22.96760151 -22.63632226 -22.43465026 -22.5701487  -22.76443827
#  -22.89497913 -22.92254141 -22.93607433 -22.93646464 -22.93340082
#  -38.378212  ]
# time_constant_param_ls [tensor([9.8712], requires_grad=True), tensor([2.6502], requires_grad=True)]
# No change point!
# Batch 4
# [tensor([9.8712]), tensor([2.6502])]
# 28.0
# Final kernel size:  40
# Temperature:  tensor([[1.0000, 0.7773, 1.0000],
#         [1.0000, 0.7245, 1.0000],
#         [1.0000, 0.3991, 1.0000]])
# new_construct_vals:  [tensor([[28.1194]], requires_grad=True), tensor([[28.1194]], requires_grad=True)]
# tmp_occurence_times:  [30 10]
# 0 [30 10]
# [[  2.20519729  -5.95928651 -10.61177799]
#  [  9.98225979  -6.60819003 -20.43859949]
#  [ 13.17038804  -2.43401395 -20.87132737]]
# final construct vals:  [tensor([[28.1189]], requires_grad=True), tensor([[28.0738]], requires_grad=True)]
# 1 [31  9]
# [[  1.80219121  -0.64551704  -9.4840215 ]
#  [ 10.04108695  -1.27922143 -16.99512336]
#  [ 12.1294828   -1.63150294 -19.89144563]]
# final construct vals:  [tensor([[28.0853]], requires_grad=True), tensor([[28.0425]], requires_grad=True)]
# 2 [32  8]
# [[  1.79028896  -0.64676169  -9.48565382]
#  [ 10.03738162  -1.27665122 -16.99796494]
#  [ 12.1400933   -1.62037137 -19.88954661]]
# final construct vals:  [tensor([[28.0860]], requires_grad=True), tensor([[28.0366]], requires_grad=True)]
# 3 [33  7]
# [[  1.78907252  -0.64954855  -9.48557362]
#  [ 10.03860301  -1.27808266 -16.99666909]
#  [ 12.13282865  -1.61658673 -19.88833013]]
# final construct vals:  [tensor([[28.0823]], requires_grad=True), tensor([[28.0389]], requires_grad=True)]
# 4 [34  6]
# [[  1.79692888  -0.65529038  -9.4841549 ]
#  [ 10.04960525  -1.27885759 -16.99612806]
#  [ 12.10668172  -1.61546155 -19.88508932]]
# final construct vals:  [tensor([[28.0756]], requires_grad=True), tensor([[28.0514]], requires_grad=True)]
# 5 [35  5]
# [[  1.82589485  -0.66680052  -9.47364616]
#  [ 10.11517246  -1.28726957 -16.96063946]
#  [ 11.98992829  -1.62522368 -19.86846873]]
# final construct vals:  [tensor([[28.0592]], requires_grad=True), tensor([[28.1203]], requires_grad=True)]
# 6 [36  4]
# [[  1.83575375  -0.67068313  -9.45851323]
#  [ 10.21435683  -1.29280485 -16.89944298]
#  [ 11.86883435  -1.6325822  -19.84502424]]
# final construct vals:  [tensor([[28.0485]], requires_grad=True), tensor([[28.2298]], requires_grad=True)]
# 7 [37  3]
# [[  1.82637464  -0.66422132  -9.44333379]
#  [ 10.2428229   -1.29320254 -16.84500122]
#  [ 11.84461906  -1.61876498 -19.83416941]]
# final construct vals:  [tensor([[28.0471]], requires_grad=True), tensor([[28.3985]], requires_grad=True)]
# 8 [38  2]
# [[  1.81513938  -0.65332833  -9.44676038]
#  [ 10.20302493  -1.27069706 -16.91475192]
#  [ 11.9557847   -1.58402395 -19.84657143]]
# final construct vals:  [tensor([[28.0547]], requires_grad=True), tensor([[28.5809]], requires_grad=True)]
# 9 [39  1]
# [[  1.79982148  -0.65583506  -9.46813232]
#  [ 10.11606042  -1.31662704 -16.98258034]
#  [ 12.05198008  -1.60579318 -19.87229187]]
# final construct vals:  [tensor([[28.0687]], requires_grad=True), tensor([[28.6448]], requires_grad=True)]
# 10 [40  0]
# [[  1.80236572  -0.66031222  -9.48053892]
#  [ 10.07868954  -1.28464347 -16.98499429]
#  [ 12.06419164  -1.62078266 -19.87865814]]
# final construct vals:  [tensor([[28.0710]], requires_grad=True), tensor([[28.6448]], requires_grad=True)]
# [-25.96468279 -25.93339782 -25.74218405 -25.78487666 -25.8801057
#  -25.95105252 -25.96176595 -25.95428661 -25.94918579 -25.95407093
#  -41.56535021]
# time_constant_param_ls [tensor([9.8711], requires_grad=True), tensor([2.6503], requires_grad=True)]
# No change point!
# Batch 5
# [tensor([9.8711]), tensor([2.6503])]
# 28.0
# Final kernel size:  40
# Temperature:  tensor([[1.0000, 0.7319, 1.0000],
#         [1.0000, 0.7176, 1.0000],
#         [1.0000, 0.3953, 1.0000]])
# new_construct_vals:  [tensor([[28.0710]], requires_grad=True), tensor([[28.0710]], requires_grad=True)]
# tmp_occurence_times:  [30 10]
# 0 [30 10]
# [[  2.56963847  -5.9638677  -11.20200062]
#  [ 10.03739538  -6.58567145 -20.61135797]
#  [ 12.7530639   -2.37896066 -20.88766418]]
# final construct vals:  [tensor([[28.1029]], requires_grad=True), tensor([[28.1215]], requires_grad=True)]
# 1 [31  9]
# [[  1.67264461  -0.69018468 -10.11265527]
#  [ 10.06674636  -1.35858887 -17.15943054]
#  [ 11.66116338  -1.81104246 -19.98982475]]
# final construct vals:  [tensor([[28.0749]], requires_grad=True), tensor([[28.1212]], requires_grad=True)]
# 2 [32  8]
# [[  1.67106934  -0.69057331 -10.10898514]
#  [ 10.07708177  -1.35875761 -17.15152473]
#  [ 11.64678582  -1.80992944 -19.98294142]]
# final construct vals:  [tensor([[28.0708]], requires_grad=True), tensor([[28.1359]], requires_grad=True)]
# 3 [33  7]
# [[  1.68242436  -0.69283276 -10.10366699]
#  [ 10.09514189  -1.36200687 -17.12925166]
#  [ 11.6221495   -1.81388012 -19.97545153]]
# final construct vals:  [tensor([[28.0640]], requires_grad=True), tensor([[28.1655]], requires_grad=True)]
# 4 [34  6]
# [[  1.68896985  -0.69669569 -10.08922959]
#  [ 10.19618142  -1.35034046 -17.08483426]
#  [ 11.55762575  -1.82169158 -19.95661437]]
# final construct vals:  [tensor([[28.0492]], requires_grad=True), tensor([[28.2455]], requires_grad=True)]
# 5 [35  5]
# [[  1.66805857  -0.68963182 -10.07368911]
#  [ 10.30461561  -1.33904838 -17.02248044]
#  [ 11.52715413  -1.81159413 -19.93587116]]
# final construct vals:  [tensor([[28.0421]], requires_grad=True), tensor([[28.3564]], requires_grad=True)]
# 6 [36  4]
# [[  1.64030412  -0.67010176 -10.06313096]
#  [ 10.30570293  -1.32166701 -16.99657138]
#  [ 11.60917821  -1.77636662 -19.93810735]]
# final construct vals:  [tensor([[28.0456]], requires_grad=True), tensor([[28.5144]], requires_grad=True)]
# 7 [37  3]
# [[  1.6350636   -0.65538235 -10.06192524]
#  [ 10.25921377  -1.30793316 -17.08264381]
#  [ 11.74527511  -1.72564263 -19.95432217]]
# final construct vals:  [tensor([[28.0573]], requires_grad=True), tensor([[28.7282]], requires_grad=True)]
# 8 [38  2]
# [[  1.65065037  -0.64744519 -10.08360375]
#  [ 10.17812661  -1.32932625 -17.21721738]
#  [ 11.78855447  -1.73698176 -19.98990206]]
# final construct vals:  [tensor([[28.0761]], requires_grad=True), tensor([[28.8839]], requires_grad=True)]
# 9 [39  1]
# [[  1.65018793  -0.66700404 -10.10926259]
#  [ 10.11240333  -1.40425148 -17.22777327]
#  [ 11.71605789  -1.80854808 -19.99506141]]
# final construct vals:  [tensor([[28.0913]], requires_grad=True), tensor([[28.8132]], requires_grad=True)]
# 10 [40  0]
# [[  1.64119219  -0.67814328 -10.11374771]
#  [ 10.07007593  -1.36556202 -17.16189272]
#  [ 11.68110677  -1.8157558  -19.99261942]]
# final construct vals:  [tensor([[28.0932]], requires_grad=True), tensor([[28.8132]], requires_grad=True)]
# [-27.73534607 -27.73325171 -27.38714493 -27.14829687 -27.21075982
#  -27.37248674 -27.55662892 -27.67737418 -27.70777472 -27.72117221
#  -42.26942483]
# time_constant_param_ls [tensor([9.8710], requires_grad=True), tensor([2.6504], requires_grad=True)]
# No change point!
# Batch 6
# [tensor([9.8710]), tensor([2.6504])]
# 28.0
# Final kernel size:  40
# Temperature:  tensor([[1.0000, 0.6904, 1.0000],
#         [1.0000, 0.7235, 1.0000],
#         [1.0000, 0.3986, 1.0000]])
# new_construct_vals:  [tensor([[28.0932]], requires_grad=True), tensor([[28.0932]], requires_grad=True)]
# tmp_occurence_times:  [30 10]
# 0 [30 10]
# [[  3.2829939   -5.9769104  -11.85655947]
#  [  9.93669443  -6.49631581 -20.42481209]
#  [ 14.30184916  -1.46346026 -20.80076983]]
# final construct vals:  [tensor([[28.1456]], requires_grad=True), tensor([[28.1418]], requires_grad=True)]
# 1 [31  9]
# [[  2.24748732  -0.63908191 -10.72708164]
#  [  9.83970525  -1.22963149 -16.99604391]
#  [ 12.98305429  -1.29310033 -19.88328156]]
# final construct vals:  [tensor([[28.1035]], requires_grad=True), tensor([[28.1265]], requires_grad=True)]
# 2 [32  8]
# [[  2.26248227  -0.63669536 -10.72085252]
#  [  9.86046452  -1.23328759 -16.97614747]
#  [ 12.94395824  -1.30355556 -19.87393141]]
# final construct vals:  [tensor([[28.0930]], requires_grad=True), tensor([[28.1540]], requires_grad=True)]
# 3 [33  7]
# [[  2.28456956  -0.63680833 -10.70866208]
#  [  9.96008094  -1.22305665 -16.93910596]
#  [ 12.86470105  -1.32198485 -19.857559  ]]
# final construct vals:  [tensor([[28.0736]], requires_grad=True), tensor([[28.2238]], requires_grad=True)]
# 4 [34  6]
# [[  2.2772308   -0.62604558 -10.69542982]
#  [ 10.08739291  -1.20591991 -16.88763116]
#  [ 12.80498035  -1.31504948 -19.84064698]]
# final construct vals:  [tensor([[28.0621]], requires_grad=True), tensor([[28.3194]], requires_grad=True)]
# 5 [35  5]
# [[  2.25759415  -0.60473175 -10.68779287]
#  [ 10.12999001  -1.17734881 -16.86983684]
#  [ 12.84704523  -1.27265611 -19.84585628]]
# final construct vals:  [tensor([[28.0619]], requires_grad=True), tensor([[28.4436]], requires_grad=True)]
# 6 [36  4]
# [[  2.25267976  -0.58842719 -10.68988835]
#  [ 10.12022246  -1.14207792 -16.95211   ]
#  [ 12.94850832  -1.21271226 -19.8609079 ]]
# final construct vals:  [tensor([[28.0707]], requires_grad=True), tensor([[28.5919]], requires_grad=True)]
# 7 [37  3]
# [[  2.26145911  -0.58592367 -10.70037571]
#  [ 10.05274595  -1.17054764 -17.02014438]
#  [ 13.01557584  -1.20811784 -19.88188992]]
# final construct vals:  [tensor([[28.0863]], requires_grad=True), tensor([[28.7304]], requires_grad=True)]
# 8 [38  2]
# [[  2.25662542  -0.60214668 -10.71564256]
#  [ 10.01203416  -1.17508468 -17.11155794]
#  [ 13.00455805  -1.258299   -19.88495956]]
# final construct vals:  [tensor([[28.1016]], requires_grad=True), tensor([[28.8395]], requires_grad=True)]
# 9 [39  1]
# [[  2.234276    -0.62658259 -10.72481229]
#  [  9.88103745  -1.25894777 -17.04721895]
#  [ 12.98885276  -1.28308147 -19.88422083]]
# final construct vals:  [tensor([[28.1122]], requires_grad=True), tensor([[28.6520]], requires_grad=True)]
# 10 [40  0]
# [[  2.2304827   -0.63074463 -10.72680687]
#  [  9.83296643  -1.22928574 -16.99617384]
#  [ 12.99059122  -1.28724301 -19.88482974]]
# final construct vals:  [tensor([[28.1123]], requires_grad=True), tensor([[28.6520]], requires_grad=True)]
# [-25.70104349 -25.7206977  -25.47447279 -25.23721826 -25.12471309
#  -25.22359326 -25.40111886 -25.57782531 -25.67756487 -25.69797399
#  -39.49729038]
# time_constant_param_ls [tensor([9.8711], requires_grad=True), tensor([2.6504], requires_grad=True)]
# No change point!
# Batch 7
# [tensor([9.8711]), tensor([2.6504])]
# 28.0
# Final kernel size:  40
# Temperature:  tensor([[1.0000, 0.6179, 1.0000],
#         [1.0000, 0.7417, 1.0000],
#         [1.0000, 0.4085, 1.0000]])
# new_construct_vals:  [tensor([[28.1123]], requires_grad=True), tensor([[28.1123]], requires_grad=True)]
# tmp_occurence_times:  [30 10]
# 0 [30 10]
# [[  3.29007706  -6.03873286 -13.16493638]
#  [  9.82350435  -6.4793475  -19.96755164]
#  [ 13.75738053  -1.79200842 -20.18853225]]
# final construct vals:  [tensor([[28.1429]], requires_grad=True), tensor([[28.1388]], requires_grad=True)]
# 1 [31  9]
# [[  2.89483676  -0.6823279  -11.91043856]
#  [  9.8118769   -1.24515728 -16.60206188]
#  [ 12.38515874  -1.4817358  -19.1726559 ]]
# final construct vals:  [tensor([[28.1125]], requires_grad=True), tensor([[28.1164]], requires_grad=True)]
# 2 [32  8]
# [[  2.94604601  -0.68367672 -11.89678166]
#  [  9.89181343  -1.24744677 -16.56949871]
#  [ 12.27862329  -1.52024278 -19.15445042]]
# final construct vals:  [tensor([[28.0894]], requires_grad=True), tensor([[28.1758]], requires_grad=True)]
# 3 [33  7]
# [[  2.98575785  -0.67455781 -11.88547801]
#  [ 10.00882648  -1.23211299 -16.52852091]
#  [ 12.17061248  -1.52933193 -19.14134201]]
# final construct vals:  [tensor([[28.0731]], requires_grad=True), tensor([[28.2551]], requires_grad=True)]
# 4 [34  6]
# [[  3.00937442  -0.65550136 -11.88070463]
#  [ 10.05770816  -1.20066693 -16.51541816]
#  [ 12.14755657  -1.48962104 -19.14587027]]
# final construct vals:  [tensor([[28.0687]], requires_grad=True), tensor([[28.3474]], requires_grad=True)]
# 5 [35  5]
# [[  3.02727177  -0.64057514 -11.88436656]
#  [ 10.0595599   -1.1627824  -16.574312  ]
#  [ 12.19017544  -1.42281577 -19.15782345]]
# final construct vals:  [tensor([[28.0735]], requires_grad=True), tensor([[28.4508]], requires_grad=True)]
# 6 [36  4]
# [[  3.02496389  -0.63707462 -11.89378211]
#  [ 10.00349363  -1.1656885  -16.62940154]
#  [ 12.25231641  -1.39540178 -19.17345399]]
# final construct vals:  [tensor([[28.0858]], requires_grad=True), tensor([[28.5444]], requires_grad=True)]
# 7 [37  3]
# [[  2.99840792  -0.64486676 -11.90511991]
#  [  9.95404823  -1.18285367 -16.67079308]
#  [ 12.2983058   -1.4089405  -19.18002235]]
# final construct vals:  [tensor([[28.0978]], requires_grad=True), tensor([[28.6570]], requires_grad=True)]
# 8 [38  2]
# [[  2.93105924  -0.66581891 -11.90827321]
#  [  9.89110407  -1.21347603 -16.68538209]
#  [ 12.34710573  -1.43926777 -19.17402638]]
# final construct vals:  [tensor([[28.1086]], requires_grad=True), tensor([[28.6894]], requires_grad=True)]
# 9 [39  1]
# [[  2.89053923  -0.67986195 -11.90711239]
#  [  9.83532555  -1.26391025 -16.63425131]
#  [ 12.38130219  -1.47410222 -19.1706658 ]]
# final construct vals:  [tensor([[28.1152]], requires_grad=True), tensor([[28.5798]], requires_grad=True)]
# 10 [40  0]
# [[  2.88583105  -0.68101008 -11.90692975]
#  [  9.80811421  -1.24740117 -16.60047655]
#  [ 12.38600711  -1.47812577 -19.16785649]]
# final construct vals:  [tensor([[28.1146]], requires_grad=True), tensor([[28.5798]], requires_grad=True)]
# [-26.00184744 -26.02273695 -25.91697534 -25.74183434 -25.61402862
#  -25.56566821 -25.67314323 -25.82614684 -25.95561434 -26.00250493
#  -40.7601471 ]
# time_constant_param_ls [tensor([9.8711], requires_grad=True), tensor([2.6505], requires_grad=True)]
# No change point!
# Batch 8
# [tensor([9.8711]), tensor([2.6505])]
# 28.0
# Final kernel size:  40
# Temperature:  tensor([[1.0000, 0.6017, 1.0000],
#         [1.0000, 0.7685, 1.0000],
#         [1.0000, 0.4234, 1.0000]])
# new_construct_vals:  [tensor([[28.1146]], requires_grad=True), tensor([[28.1146]], requires_grad=True)]
# tmp_occurence_times:  [30 10]
# 0 [30 10]
# [[  3.55851008  -5.81840619 -13.54564509]
#  [  9.74910154  -6.27587278 -19.27845214]
#  [ 13.49249436  -2.07013333 -19.36446232]]
# final construct vals:  [tensor([[28.1387]], requires_grad=True), tensor([[28.0764]], requires_grad=True)]
# 1 [31  9]
# [[  3.00365024  -0.58743169 -12.28721945]
#  [  9.77524552  -1.09703409 -15.93873005]
#  [ 11.81076299  -1.71288766 -18.36832131]]
# final construct vals:  [tensor([[28.0962]], requires_grad=True), tensor([[28.0580]], requires_grad=True)]
# 2 [32  8]
# [[  3.04628127  -0.57993091 -12.2806172 ]
#  [  9.84018812  -1.10273097 -15.91104153]
#  [ 11.6947712   -1.75487433 -18.35833691]]
# final construct vals:  [tensor([[28.0767]], requires_grad=True), tensor([[28.1046]], requires_grad=True)]
# 3 [33  7]
# [[  3.07301662  -0.57192789 -12.27809803]
#  [  9.87812978  -1.09742843 -15.89767949]
#  [ 11.63020408  -1.75666293 -18.35729253]]
# final construct vals:  [tensor([[28.0680]], requires_grad=True), tensor([[28.1500]], requires_grad=True)]
# 4 [34  6]
# [[  3.08474248  -0.56585499 -12.27944141]
#  [  9.8768197   -1.08635847 -15.9140173 ]
#  [ 11.61997224  -1.7308181  -18.36134218]]
# final construct vals:  [tensor([[28.0677]], requires_grad=True), tensor([[28.1885]], requires_grad=True)]
# 5 [35  5]
# [[  3.07018809  -0.56855841 -12.28244506]
#  [  9.83865806  -1.08833935 -15.92806882]
#  [ 11.66128498  -1.71810801 -18.36507702]]
# final construct vals:  [tensor([[28.0745]], requires_grad=True), tensor([[28.1868]], requires_grad=True)]
# 6 [36  4]
# [[  3.04119952  -0.5774276  -12.28334438]
#  [  9.81487826  -1.09551132 -15.92822664]
#  [ 11.71503856  -1.72994695 -18.36332954]]
# final construct vals:  [tensor([[28.0814]], requires_grad=True), tensor([[28.1361]], requires_grad=True)]
# 7 [37  3]
# [[  3.01857355  -0.5855751  -12.28130462]
#  [  9.81823436  -1.106985   -15.91233342]
#  [ 11.76376006  -1.75628966 -18.35962943]]
# final construct vals:  [tensor([[28.0867]], requires_grad=True), tensor([[27.9918]], requires_grad=True)]
# 8 [38  2]
# [[  3.02232929  -0.5856332  -12.27988196]
#  [  9.85559556  -1.11640893 -15.89349802]
#  [ 11.7655209   -1.77190389 -18.35719564]]
# final construct vals:  [tensor([[28.0881]], requires_grad=True), tensor([[27.7389]], requires_grad=True)]
# 9 [39  1]
# [[  3.02855627  -0.58233511 -12.2815393 ]
#  [  9.83980694  -1.09706828 -15.90709946]
#  [ 11.74462926  -1.75216745 -18.36062804]]
# final construct vals:  [tensor([[28.0858]], requires_grad=True), tensor([[27.5955]], requires_grad=True)]
# 10 [40  0]
# [[  3.02803086  -0.58196003 -12.28257417]
#  [  9.81108196  -1.10169964 -15.92153201]
#  [ 11.74068168  -1.74062392 -18.36153795]]
# final construct vals:  [tensor([[28.0840]], requires_grad=True), tensor([[27.5955]], requires_grad=True)]
# [-25.41013323 -25.36784518 -25.36107588 -25.40154926 -25.4066701
#  -25.38046553 -25.35629804 -25.37773882 -25.40629125 -25.40196553
#  -39.55286586]
# time_constant_param_ls [tensor([9.8711], requires_grad=True), tensor([2.6506], requires_grad=True)]
# No change point!
# Batch 9
# [tensor([9.8711]), tensor([2.6506])]
# 28.0
# Final kernel size:  40
# Temperature:  tensor([[1.0000, 0.6140, 1.0000],
#         [1.0000, 0.8062, 1.0000],
#         [1.0000, 0.4441, 1.0000]])
# new_construct_vals:  [tensor([[28.0840]], requires_grad=True), tensor([[28.0840]], requires_grad=True)]
# tmp_occurence_times:  [30 10]
# 0 [30 10]
# [[  3.86717432  -5.76377889 -13.33056152]
#  [  8.22843209  -6.29583194 -18.44975889]
#  [ 13.46607177  -1.71278008 -18.21157918]]
# final construct vals:  [tensor([[28.1188]], requires_grad=True), tensor([[28.0285]], requires_grad=True)]
# 1 [31  9]
# [[  3.11935225  -0.54065046 -12.15922502]
#  [  8.44456354  -1.13735124 -15.12099909]
#  [ 11.9034944   -1.37595687 -17.29118199]]
# final construct vals:  [tensor([[28.0757]], requires_grad=True), tensor([[28.0015]], requires_grad=True)]
# 2 [32  8]
# [[  3.12367984  -0.53790811 -12.15642841]
#  [  8.46842037  -1.14161506 -15.10758935]
#  [ 11.86452823  -1.39618649 -17.28397849]]
# final construct vals:  [tensor([[28.0693]], requires_grad=True), tensor([[28.0023]], requires_grad=True)]
# 3 [33  7]
# [[  3.11950961  -0.54338837 -12.15471521]
#  [  8.49848262  -1.14331329 -15.09524125]
#  [ 11.86680776  -1.41761102 -17.28064096]]
# final construct vals:  [tensor([[28.0700]], requires_grad=True), tensor([[27.9723]], requires_grad=True)]
# 4 [34  6]
# [[  3.10231413  -0.55677781 -12.15005458]
#  [  8.59443239  -1.13735499 -15.08042083]
#  [ 11.89987784  -1.45682669 -17.27336186]]
# final construct vals:  [tensor([[28.0768]], requires_grad=True), tensor([[27.8716]], requires_grad=True)]
# 5 [35  5]
# [[  3.10045525  -0.56802546 -12.14108885]
#  [  8.77932775  -1.13619637 -15.05066733]
#  [ 11.93427047  -1.50706906 -17.26654861]]
# final construct vals:  [tensor([[28.0824]], requires_grad=True), tensor([[27.6790]], requires_grad=True)]
# 6 [36  4]
# [[  3.14266869  -0.57066175 -12.13363465]
#  [  9.11830729  -1.12452312 -15.02693743]
#  [ 11.93713946  -1.58240357 -17.26008797]]
# final construct vals:  [tensor([[28.0854]], requires_grad=True), tensor([[27.2826]], requires_grad=True)]
# 7 [37  3]
# [[  3.20500809  -0.55845266 -12.13149461]
#  [  9.52386945  -1.11090807 -15.04441982]
#  [ 11.87052112  -1.61386148 -17.25215103]]
# final construct vals:  [tensor([[28.0824]], requires_grad=True), tensor([[26.6492]], requires_grad=True)]
# 8 [38  2]
# [[  3.19941936  -0.54040712 -12.13912019]
#  [  9.55758333  -1.13438171 -15.06080463]
#  [ 11.82033356  -1.53304282 -17.26721506]]
# final construct vals:  [tensor([[28.0720]], requires_grad=True), tensor([[25.9909]], requires_grad=True)]
# 9 [39  1]
# [[  3.15962817  -0.52918171 -12.15070352]
#  [  8.85221617  -1.15370046 -15.09219567]
#  [ 11.79422033  -1.42569981 -17.27788157]]
# final construct vals:  [tensor([[28.0581]], requires_grad=True), tensor([[25.6250]], requires_grad=True)]
# 10 [40  0]
# [[  3.15350798  -0.5266619  -12.15766543]
#  [  8.47745172  -1.1617846  -15.08834036]
#  [ 11.7864959   -1.39370091 -17.28250347]]
# final construct vals:  [tensor([[28.0530]], requires_grad=True), tensor([[25.6250]], requires_grad=True)]
# [-24.19320106 -23.82329807 -23.09763527 -23.11188901 -23.50013305
#  -23.8555422  -24.05817241 -24.15011012 -24.16707746 -24.15795448
#  -38.20261232]
# time_constant_param_ls [tensor([9.8712], requires_grad=True), tensor([2.6506], requires_grad=True)]
# No change point!
# Batch 10
# [tensor([9.8712]), tensor([2.6506])]
# 28.0
# Final kernel size:  40
# Temperature:  tensor([[1.0000, 0.6350, 1.0000],
#         [1.0000, 0.8321, 1.0000],
#         [1.0000, 0.4584, 1.0000]])
# new_construct_vals:  [tensor([[28.0530]], requires_grad=True), tensor([[28.0530]], requires_grad=True)]
# tmp_occurence_times:  [30 10]
# 0 [30 10]
# [[  3.63011525  -5.19737281 -12.74220435]
#  [  6.68284746  -6.75742186 -17.81938891]
#  [ 13.10181542  -1.5070202  -17.26880228]]
# final construct vals:  [tensor([[28.1004]], requires_grad=True), tensor([[27.9700]], requires_grad=True)]
# 1 [31  9]
# [[  3.55275752  -0.53470576 -11.90277697]
#  [  7.21646614  -1.53517034 -14.4420797 ]
#  [ 11.11247401  -1.19970223 -16.39276111]]
# final construct vals:  [tensor([[28.0397]], requires_grad=True), tensor([[27.9213]], requires_grad=True)]
# 2 [32  8]
# [[  3.51631562  -0.54416632 -11.89547851]
#  [  7.35378988  -1.50960375 -14.41363243]
#  [ 11.09033116  -1.24241783 -16.38090738]]
# final construct vals:  [tensor([[28.0457]], requires_grad=True), tensor([[27.8539]], requires_grad=True)]
# 3 [33  7]
# [[  3.47195608  -0.56659674 -11.88353059]
#  [  7.66451585  -1.4557298  -14.38899932]
#  [ 11.09253671  -1.3090795  -16.36842032]]
# final construct vals:  [tensor([[28.0566]], requires_grad=True), tensor([[27.7035]], requires_grad=True)]
# 4 [34  6]
# [[  3.45537316  -0.58162588 -11.8666375 ]
#  [  8.15677743  -1.4040709  -14.34794021]
#  [ 11.09400381  -1.37667454 -16.35954543]]
# final construct vals:  [tensor([[28.0647]], requires_grad=True), tensor([[27.4467]], requires_grad=True)]
# 5 [35  5]
# [[  3.50575313  -0.57620334 -11.85592982]
#  [  8.86594407  -1.32597829 -14.33169674]
#  [ 11.05815721  -1.45365522 -16.35547705]]
# final construct vals:  [tensor([[28.0683]], requires_grad=True), tensor([[27.0230]], requires_grad=True)]
# 6 [36  4]
# [[  3.58159898  -0.55757685 -11.85306973]
#  [  9.62757873  -1.27102722 -14.35385881]
#  [ 10.98587922  -1.48314634 -16.34820714]]
# final construct vals:  [tensor([[28.0647]], requires_grad=True), tensor([[26.3479]], requires_grad=True)]
# 7 [37  3]
# [[  3.60538297  -0.53661088 -11.86102233]
#  [  9.82791009  -1.23287129 -14.43666814]
#  [ 10.9967248   -1.39332653 -16.36370819]]
# final construct vals:  [tensor([[28.0517]], requires_grad=True), tensor([[25.5464]], requires_grad=True)]
# 8 [38  2]
# [[  3.59687737  -0.52011164 -11.8786788 ]
#  [  8.91413818  -1.41386838 -14.41773101]
#  [ 11.03677547  -1.26572371 -16.37653898]]
# final construct vals:  [tensor([[28.0311]], requires_grad=True), tensor([[24.8856]], requires_grad=True)]
# 9 [39  1]
# [[  3.61073086  -0.50927846 -11.90257475]
#  [  7.62723965  -1.60522986 -14.41417939]
#  [ 11.009487    -1.196188   -16.38465457]]
# final construct vals:  [tensor([[28.0118]], requires_grad=True), tensor([[24.5215]], requires_grad=True)]
# 10 [40  0]
# [[  3.61771242  -0.50867584 -11.90950712]
#  [  7.16425413  -1.59425207 -14.40004605]
#  [ 11.00023346  -1.19192824 -16.38451436]]
# final construct vals:  [tensor([[28.0083]], requires_grad=True), tensor([[24.5215]], requires_grad=True)]
# [-24.20672368 -23.76464752 -22.3248615  -21.3941895  -21.67182917
#  -22.46908604 -23.23034006 -23.74334763 -24.02576955 -24.12549843
#  -37.87743228]
# time_constant_param_ls [tensor([9.8713], requires_grad=True), tensor([2.6507], requires_grad=True)]
# No change point!
# Batch 11
# [tensor([9.8713]), tensor([2.6507])]
# 28.0
# Final kernel size:  40
# Temperature:  tensor([[1.0000, 0.6490, 1.0000],
#         [1.0000, 0.8100, 1.0000],
#         [1.0000, 0.4462, 1.0000]])
# new_construct_vals:  [tensor([[28.0083]], requires_grad=True), tensor([[28.0083]], requires_grad=True)]
# tmp_occurence_times:  [30 10]
# 0 [30 10]
# [[  3.14849242  -5.13180183 -11.85752418]
#  [  8.81569309  -6.89128615 -17.56081288]
#  [ 12.14505195  -2.00854524 -17.35540105]]
# final construct vals:  [tensor([[28.1488]], requires_grad=True), tensor([[28.0007]], requires_grad=True)]
# 1 [31  9]
# [[  3.12564018  -0.57846424 -11.24586691]
#  [  8.28392522  -1.4904622  -14.45349136]
#  [ 10.17477646  -1.48925706 -16.63053153]]
# final construct vals:  [tensor([[28.1221]], requires_grad=True), tensor([[28.0271]], requires_grad=True)]
# 2 [32  8]
# [[  3.0524639   -0.58629983 -11.23453633]
#  [  8.47915129  -1.47485879 -14.43306095]
#  [ 10.16317424  -1.54872554 -16.62131638]]
# final construct vals:  [tensor([[28.1319]], requires_grad=True), tensor([[27.9441]], requires_grad=True)]
# 3 [33  7]
# [[  2.99230941  -0.59838092 -11.2218941 ]
#  [  8.77248001  -1.46156625 -14.40467935]
#  [ 10.15251138  -1.61708306 -16.61604065]]
# final construct vals:  [tensor([[28.1399]], requires_grad=True), tensor([[27.7944]], requires_grad=True)]
# 4 [34  6]
# [[  2.96775679  -0.59855061 -11.21198505]
#  [  9.14525601  -1.43547624 -14.38694567]
#  [ 10.11331398  -1.68368382 -16.61333277]]
# final construct vals:  [tensor([[28.1444]], requires_grad=True), tensor([[27.5513]], requires_grad=True)]
# 5 [35  5]
# [[  2.97966278  -0.58814997 -11.20767042]
#  [  9.40778685  -1.41247601 -14.39251724]
#  [ 10.06137839  -1.69663318 -16.60977643]]
# final construct vals:  [tensor([[28.1425]], requires_grad=True), tensor([[27.2089]], requires_grad=True)]
# 6 [36  4]
# [[  3.01313087  -0.57408182 -11.21208001]
#  [  9.23254954  -1.38550589 -14.42339184]
#  [ 10.07615757  -1.61996498 -16.61828587]]
# final construct vals:  [tensor([[28.1331]], requires_grad=True), tensor([[26.8495]], requires_grad=True)]
# 7 [37  3]
# [[  3.08622557  -0.5610362  -11.22549982]
#  [  8.56622352  -1.41046063 -14.4453376 ]
#  [ 10.11525013  -1.50307969 -16.62331085]]
# final construct vals:  [tensor([[28.1169]], requires_grad=True), tensor([[26.7403]], requires_grad=True)]
# 8 [38  2]
# [[  3.17509576  -0.55330483 -11.24234749]
#  [  8.09018743  -1.48919444 -14.42742718]
#  [ 10.12111589  -1.4434668  -16.62551031]]
# final construct vals:  [tensor([[28.1041]], requires_grad=True), tensor([[27.1474]], requires_grad=True)]
# 9 [39  1]
# [[  3.19613747  -0.55248247 -11.24997972]
#  [  8.1120045   -1.50492281 -14.43634439]
#  [ 10.10752279  -1.43077736 -16.62603474]]
# final construct vals:  [tensor([[28.1012]], requires_grad=True), tensor([[27.4142]], requires_grad=True)]
# 10 [40  0]
# [[  3.19752244  -0.55292231 -11.25112506]
#  [  8.15583284  -1.50481359 -14.44489059]
#  [ 10.10579545  -1.42984857 -16.62684402]]
# final construct vals:  [tensor([[28.1017]], requires_grad=True), tensor([[27.4142]], requires_grad=True)]
# [-24.35129341 -24.38487674 -24.39485197 -24.00102557 -23.51147244
#  -23.45839524 -23.70364739 -24.00234353 -24.2040084  -24.30373143
#  -36.69613387]
# time_constant_param_ls [tensor([9.8713], requires_grad=True), tensor([2.6508], requires_grad=True)]
# No change point!
# Batch 12
# [tensor([9.8713]), tensor([2.6508])]
# 28.0
# Final kernel size:  40
# Temperature:  tensor([[1.0000, 0.6919, 1.0000],
#         [1.0000, 0.7523, 1.0000],
#         [1.0000, 0.4144, 1.0000]])
# new_construct_vals:  [tensor([[28.1017]], requires_grad=True), tensor([[28.1017]], requires_grad=True)]
# tmp_occurence_times:  [30 10]
# 0 [30 10]
# [[  3.83167905  -5.1828441  -10.87968767]
#  [  8.84343988  -7.15012368 -17.03098854]
#  [ 12.51709183  -2.42587538 -18.33911733]]
# final construct vals:  [tensor([[28.1900]], requires_grad=True), tensor([[27.9648]], requires_grad=True)]
# 1 [31  9]
# [[  2.93259331  -0.64445232 -10.24350409]
#  [  8.81863659  -1.85130964 -13.9809978 ]
#  [ 10.87143124  -1.71395327 -17.45509206]]
# final construct vals:  [tensor([[28.1710]], requires_grad=True), tensor([[27.8757]], requires_grad=True)]
# 2 [32  8]
# [[  2.89660279  -0.64713961 -10.22779287]
#  [  9.1610871   -1.81860941 -13.93782334]
#  [ 10.84619127  -1.78156678 -17.44454417]]
# final construct vals:  [tensor([[28.1773]], requires_grad=True), tensor([[27.7180]], requires_grad=True)]
# 3 [33  7]
# [[  2.91924658  -0.64164206 -10.21895958]
#  [  9.5586414   -1.77129369 -13.92041573]
#  [ 10.80956381  -1.84275195 -17.44352305]]
# final construct vals:  [tensor([[28.1801]], requires_grad=True), tensor([[27.4721]], requires_grad=True)]
# 4 [34  6]
# [[  2.96307179  -0.62693575 -10.21552833]
#  [  9.81203711  -1.73349879 -13.93336428]
#  [ 10.76619547  -1.83964165 -17.44050568]]
# final construct vals:  [tensor([[28.1763]], requires_grad=True), tensor([[27.1356]], requires_grad=True)]
# 5 [35  5]
# [[  2.99580615  -0.61006557 -10.21968107]
#  [  9.60175035  -1.69346727 -13.97585493]
#  [ 10.79051886  -1.73845978 -17.44940344]]
# final construct vals:  [tensor([[28.1648]], requires_grad=True), tensor([[26.7768]], requires_grad=True)]
# 6 [36  4]
# [[  3.02922461  -0.59449497 -10.23256061]
#  [  8.90307747  -1.71245591 -14.0091464 ]
#  [ 10.82638408  -1.59456972 -17.45349466]]
# final construct vals:  [tensor([[28.1457]], requires_grad=True), tensor([[26.5976]], requires_grad=True)]
# 7 [37  3]
# [[  3.0656646   -0.58548796 -10.24677598]
#  [  8.34706549  -1.82916393 -13.98985338]
#  [ 10.81786164  -1.51655737 -17.45330488]]
# final construct vals:  [tensor([[28.1296]], requires_grad=True), tensor([[26.5549]], requires_grad=True)]
# 8 [38  2]
# [[  3.07073955  -0.58194082 -10.25686235]
#  [  8.32974086  -1.89109593 -14.00300661]
#  [ 10.78390421  -1.49078111 -17.45228434]]
# final construct vals:  [tensor([[28.1223]], requires_grad=True), tensor([[26.3881]], requires_grad=True)]
# 9 [39  1]
# [[  3.04468536  -0.58290352 -10.26285834]
#  [  8.37793298  -1.91399948 -14.02764944]
#  [ 10.74899687  -1.48532918 -17.45142578]]
# final construct vals:  [tensor([[28.1175]], requires_grad=True), tensor([[26.1854]], requires_grad=True)]
# 10 [40  0]
# [[  3.03411542  -0.58450533 -10.26441016]
#  [  8.30690431  -1.94417101 -14.01380677]
#  [ 10.73951355  -1.4847983  -17.45042663]]
# final construct vals:  [tensor([[28.1156]], requires_grad=True), tensor([[26.1854]], requires_grad=True)]
# [-23.66158492 -23.55255053 -23.49158654 -23.39055178 -22.83803609
#  -22.29885669 -22.24817011 -22.55113426 -22.95359503 -23.26664803
#  -35.81642594]
# time_constant_param_ls [tensor([9.8714], requires_grad=True), tensor([2.6508], requires_grad=True)]
# No change point!
# Batch 13
# [tensor([9.8714]), tensor([2.6508])]
# 28.0
# Final kernel size:  40
# Temperature:  tensor([[1.0000, 0.7252, 1.0000],
#         [1.0000, 0.6636, 1.0000],
#         [1.0000, 0.3655, 1.0000]])
# new_construct_vals:  [tensor([[28.1156]], requires_grad=True), tensor([[28.1156]], requires_grad=True)]
# tmp_occurence_times:  [30 10]
# 0 [30 10]
# [[  4.24173434  -5.23804121  -9.90302696]
#  [  8.37436406  -6.92692726 -18.34088315]
#  [ 12.68391485  -2.9816614  -18.76855159]]
# final construct vals:  [tensor([[28.1971]], requires_grad=True), tensor([[27.9194]], requires_grad=True)]
# 1 [31  9]
# [[  2.97178074  -0.70672062  -9.28819152]
#  [  8.0851833   -1.49265798 -15.18268302]
#  [ 11.4030596   -2.19614485 -18.06325803]]
# final construct vals:  [tensor([[28.1797]], requires_grad=True), tensor([[27.8206]], requires_grad=True)]
# 2 [32  8]
# [[  3.01595803  -0.69566829  -9.28091791]
#  [  8.27631309  -1.47043613 -15.16329455]
#  [ 11.37406685  -2.23601516 -18.06255492]]
# final construct vals:  [tensor([[28.1817]], requires_grad=True), tensor([[27.6557]], requires_grad=True)]
# 3 [33  7]
# [[  3.05399304  -0.6826135   -9.27859064]
#  [  8.31218417  -1.45149135 -15.17703098]
#  [ 11.35339037  -2.21361092 -18.06261597]]
# final construct vals:  [tensor([[28.1762]], requires_grad=True), tensor([[27.4694]], requires_grad=True)]
# 4 [34  6]
# [[  3.04633511  -0.66958704  -9.28204315]
#  [  8.04070068  -1.43115104 -15.2168988 ]
#  [ 11.37119711  -2.11310134 -18.07069876]]
# final construct vals:  [tensor([[28.1624]], requires_grad=True), tensor([[27.3474]], requires_grad=True)]
# 5 [35  5]
# [[  3.00780943  -0.66139962  -9.28916238]
#  [  7.62412355  -1.46121431 -15.24693172]
#  [ 11.38041024  -2.00809168 -18.07220869]]
# final construct vals:  [tensor([[28.1437]], requires_grad=True), tensor([[27.4377]], requires_grad=True)]
# 6 [36  4]
# [[  2.95418768  -0.65737872  -9.29925611]
#  [  7.52711092  -1.53636337 -15.25622798]
#  [ 11.34476885  -1.95157767 -18.07086465]]
# final construct vals:  [tensor([[28.1278]], requires_grad=True), tensor([[27.8047]], requires_grad=True)]
# 7 [37  3]
# [[  2.92606461  -0.65729492  -9.30336052]
#  [  7.61641724  -1.5616991  -15.26958006]
#  [ 11.32050448  -1.94064197 -18.07007775]]
# final construct vals:  [tensor([[28.1232]], requires_grad=True), tensor([[28.0917]], requires_grad=True)]
# 8 [38  2]
# [[  2.92304245  -0.6573277   -9.30395705]
#  [  7.63471569  -1.56502936 -15.27061069]
#  [ 11.31757203  -1.94001598 -18.07015678]]
# final construct vals:  [tensor([[28.1230]], requires_grad=True), tensor([[28.1904]], requires_grad=True)]
# 9 [39  1]
# [[  2.92550231  -0.65713683  -9.30392743]
#  [  7.63468463  -1.5645692  -15.27250282]
#  [ 11.31725434  -1.94021604 -18.07076558]]
# final construct vals:  [tensor([[28.1239]], requires_grad=True), tensor([[28.2890]], requires_grad=True)]
# 10 [40  0]
# [[  2.92698029  -0.65688591  -9.30377232]
#  [  7.62628784  -1.56573858 -15.26955312]
#  [ 11.31724039  -1.94029408 -18.07117643]]
# final construct vals:  [tensor([[28.1245]], requires_grad=True), tensor([[28.2890]], requires_grad=True)]
# [-24.93691193 -24.93167662 -24.9317674  -24.939668   -24.94560105
#  -24.72666519 -24.32524724 -24.14638579 -24.24254899 -24.46963239
#  -36.85907831]
# time_constant_param_ls [tensor([9.8715], requires_grad=True), tensor([2.6509], requires_grad=True)]
# No change point!
# Batch 14
# [tensor([9.8715]), tensor([2.6509])]
# 28.0
# Final kernel size:  40
# Temperature:  tensor([[1.0000, 0.7134, 1.0000],
#         [1.0000, 0.5798, 1.0000],
#         [1.0000, 0.3194, 1.0000]])
# new_construct_vals:  [tensor([[28.1245]], requires_grad=True), tensor([[28.1245]], requires_grad=True)]
# tmp_occurence_times:  [30 10]
# 0 [30 10]
# [[  4.8218336   -4.96393611  -9.53406772]
#  [  9.83689423  -7.12880809 -20.68072658]
#  [ 12.94162136  -3.00308747 -17.17695316]]
# final construct vals:  [tensor([[28.1334]], requires_grad=True), tensor([[27.8387]], requires_grad=True)]
# 1 [31  9]
# [[  4.37822563  -0.6686997   -8.92769109]
#  [  9.05878044  -1.34911404 -17.24833707]
#  [ 11.67202237  -2.40151838 -16.70893852]]
# final construct vals:  [tensor([[28.0956]], requires_grad=True), tensor([[27.7115]], requires_grad=True)]
# 2 [32  8]
# [[  4.41289211  -0.65311298  -8.92516108]
#  [  9.06660711  -1.33784072 -17.25749814]
#  [ 11.66371243  -2.3851627  -16.71196089]]
# final construct vals:  [tensor([[28.0921]], requires_grad=True), tensor([[27.5892]], requires_grad=True)]
# 3 [33  7]
# [[  4.42163028  -0.64348612  -8.92455213]
#  [  8.86469736  -1.33247985 -17.29084392]
#  [ 11.6868298   -2.32598848 -16.71973877]]
# final construct vals:  [tensor([[28.0803]], requires_grad=True), tensor([[27.5133]], requires_grad=True)]
# 4 [34  6]
# [[  4.41597763  -0.6335438   -8.9285027 ]
#  [  8.59968544  -1.36142857 -17.32107604]
#  [ 11.6924944   -2.25694189 -16.72603709]]
# final construct vals:  [tensor([[28.0620]], requires_grad=True), tensor([[27.6635]], requires_grad=True)]
# 5 [35  5]
# [[  4.39626541  -0.62883546  -8.93409544]
#  [  8.62397503  -1.42014072 -17.33856875]
#  [ 11.65932395  -2.23109197 -16.72780094]]
# final construct vals:  [tensor([[28.0471]], requires_grad=True), tensor([[28.0056]], requires_grad=True)]
# 6 [36  4]
# [[  4.38426326  -0.62831409  -8.93640462]
#  [  8.71369624  -1.44150358 -17.34485627]
#  [ 11.64185478  -2.22939273 -16.72794966]]
# final construct vals:  [tensor([[28.0435]], requires_grad=True), tensor([[28.2762]], requires_grad=True)]
# 7 [37  3]
# ...
#  [ 10.69840542  -1.52443241 -13.65895369]]
# final construct vals:  [tensor([[28.0013]], requires_grad=True), tensor([[28.3561]], requires_grad=True)]
# 3 [33  7]
# [[  4.55883571  -0.30488857  -7.51068662]
#  [ 11.42455277  -0.78188019  -7.86376401]
#  [ 10.70927253  -1.5406249  -13.67296506]]
# final construct vals:  [tensor([[28.0002]], requires_grad=True), tensor([[28.3901]], requires_grad=True)]
# 4 [34  6]
# [[  4.5735392   -0.30827509  -7.52155611]
#  [ 11.52809075  -0.78149182  -7.87323534]
#  [ 10.73390689  -1.56035708 -13.69537033]]
# final construct vals:  [tensor([[27.9977]], requires_grad=True), tensor([[28.4510]], requires_grad=True)]
# 5 [35  5]
# [[  4.57606867  -0.31213356  -7.53591171]
#  [ 11.66968731  -0.77112326  -7.8994025 ]
#  [ 10.78194156  -1.57883354 -13.72700995]]
# final construct vals:  [tensor([[27.9952]], requires_grad=True), tensor([[28.5425]], requires_grad=True)]
# 6 [36  4]
# [[  4.53472822  -0.31050014  -7.53834428]
#  [ 11.61285193  -0.77800259  -7.91160631]
#  [ 10.82351599  -1.56518359 -13.73134771]]
# final construct vals:  [tensor([[28.0019]], requires_grad=True), tensor([[28.5952]], requires_grad=True)]
# 7 [37  3]
# [[  4.43815982  -0.29773833  -7.48940465]
#  [ 11.18954806  -0.84043948  -7.85997004]
#  [ 10.75378382  -1.50501937 -13.63730306]]
# final construct vals:  [tensor([[28.0271]], requires_grad=True), tensor([[28.3997]], requires_grad=True)]
# 8 [38  2]
# [[  4.40633577  -0.28045302  -7.43342162]
#  [ 11.0403028   -0.90981307  -7.81542349]
#  [ 10.60787543  -1.45774491 -13.51716203]]
# final construct vals:  [tensor([[28.0513]], requires_grad=True), tensor([[27.9601]], requires_grad=True)]
# 9 [39  1]
# [[  4.40308799  -0.28867375  -7.44230702]
#  [ 10.97711586  -0.875853    -7.75816971]
#  [ 10.64440106  -1.4705984  -13.5419296 ]]
# final construct vals:  [tensor([[28.0440]], requires_grad=True), tensor([[28.2367]], requires_grad=True)]
# 10 [40  0]
# [[  4.4057905   -0.28427449  -7.43950624]
#  [ 11.0210131   -0.90991127  -7.79973225]
#  [ 10.62922548  -1.46556018 -13.52998164]]
# final construct vals:  [tensor([[28.0468]], requires_grad=True), tensor([[28.2367]], requires_grad=True)]
# [ -5.372937    -5.35292657  -5.35950414  -5.24838325  -4.86388847
#   -4.79671698  -4.90474894  -4.98214835  -5.02152528  -5.01251704
#  -17.4771372 ]
# time_constant_param_ls [tensor([9.8709], requires_grad=True), tensor([2.6521], requires_grad=True)]
# No change point!
# Batch 30
# [tensor([9.8709]), tensor([2.6521])]
# 28.0
# Final kernel size:  40
# Temperature:  tensor([[1.0000, 0.6755, 1.0000],
#         [1.0000, 0.6536, 1.0000],
#         [1.0000, 0.3601, 1.0000]])
# new_construct_vals:  [tensor([[28.0468]], requires_grad=True), tensor([[28.0468]], requires_grad=True)]
# tmp_occurence_times:  [30 10]
# 0 [30 10]
# [[  6.88769688  -5.58800553  -8.43089834]
#  [ 12.75344053  -4.87923595 -11.49141949]
#  [ 10.73072946  -1.90092858 -14.74970526]]
# final construct vals:  [tensor([[28.0410]], requires_grad=True), tensor([[28.3549]], requires_grad=True)]
# 1 [31  9]
# [[  6.02346523  -0.23386351  -7.41964764]
#  [ 11.65823311  -1.122315    -8.79676098]
#  [ 10.69701609  -1.58880038 -14.49643129]]
# final construct vals:  [tensor([[28.0257]], requires_grad=True), tensor([[28.2591]], requires_grad=True)]
# 2 [32  8]
# [[  6.02782578  -0.23585129  -7.42099981]
#  [ 11.68856408  -1.12078971  -8.79850901]
#  [ 10.70520934  -1.60240897 -14.50349167]]
# final construct vals:  [tensor([[28.0244]], requires_grad=True), tensor([[28.2757]], requires_grad=True)]
# 3 [33  7]
# [[  6.03689762  -0.23775471  -7.42475399]
#  [ 11.72794557  -1.12351541  -8.79836011]
#  [ 10.72410824  -1.61523042 -14.51432437]]
# final construct vals:  [tensor([[28.0226]], requires_grad=True), tensor([[28.3031]], requires_grad=True)]
# 4 [34  6]
# [[  6.0363309   -0.23978371  -7.42925043]
#  [ 11.77528787  -1.12103081  -8.80527761]
#  [ 10.75525318  -1.62665391 -14.52913716]]
# final construct vals:  [tensor([[28.0211]], requires_grad=True), tensor([[28.3408]], requires_grad=True)]
# 5 [35  5]
# [[  5.99445925  -0.23872117  -7.42591912]
#  [ 11.71853881  -1.13500367  -8.80445855]
#  [ 10.76432147  -1.61319444 -14.52060958]]
# final construct vals:  [tensor([[28.0294]], requires_grad=True), tensor([[28.3355]], requires_grad=True)]
# 6 [36  4]
# [[  5.91110049  -0.23250147  -7.40283529]
#  [ 11.57937084  -1.18652281  -8.78340212]
#  [ 10.68136103  -1.56820516 -14.46272308]]
# final construct vals:  [tensor([[28.0538]], requires_grad=True), tensor([[28.2035]], requires_grad=True)]
# 7 [37  3]
# [[  5.86603902  -0.22303743  -7.37803167]
#  [ 11.70404045  -1.24748102  -8.80694881]
#  [ 10.52981143  -1.52335572 -14.3813479 ]]
# final construct vals:  [tensor([[28.0799]], requires_grad=True), tensor([[27.9240]], requires_grad=True)]
# 8 [38  2]
# [[  5.87501027  -0.22600258  -7.38299654]
#  [ 11.68703486  -1.21266082  -8.87181194]
#  [ 10.5682698   -1.52562521 -14.39869771]]
# final construct vals:  [tensor([[28.0732]], requires_grad=True), tensor([[27.9257]], requires_grad=True)]
# 9 [39  1]
# [[  5.87520598  -0.23124189  -7.39155802]
#  [ 11.4975934   -1.00175175  -8.49376911]
#  [ 10.62796777  -1.56036204 -14.43769406]]
# final construct vals:  [tensor([[28.0551]], requires_grad=True), tensor([[28.7514]], requires_grad=True)]
# 10 [40  0]
# [[  5.88625827  -0.22587829  -7.39216114]
#  [ 11.62134794  -1.22761983  -8.79152258]
#  [ 10.59555716  -1.53867616 -14.4295049 ]]
# final construct vals:  [tensor([[28.0714]], requires_grad=True), tensor([[28.7514]], requires_grad=True)]
# [ -5.50219954  -5.11560973  -5.48747988  -5.46031164  -5.46435758
#   -5.260587    -5.18426167  -5.22498758  -5.26045127  -5.27910437
#  -16.66832627]
# time_constant_param_ls [tensor([9.8709], requires_grad=True), tensor([2.6522], requires_grad=True)]
# No change point!
# Batch 31
# [tensor([9.8709]), tensor([2.6522])]
# 28.0
# Final kernel size:  40
# Temperature:  tensor([[1.0000, 0.6859, 1.0000],
#         [1.0000, 0.6183, 1.0000],
#         [1.0000, 0.3406, 1.0000]])
# new_construct_vals:  [tensor([[28.0714]], requires_grad=True), tensor([[28.0714]], requires_grad=True)]
# tmp_occurence_times:  [30 10]
# 0 [30 10]
# [[  6.99157947  -5.56232608  -8.31597295]
#  [ 12.45253044  -5.57453576 -12.54797913]
#  [ 10.80108855  -1.92027615 -15.63015763]]
# final construct vals:  [tensor([[28.0350]], requires_grad=True), tensor([[28.3007]], requires_grad=True)]
# 1 [31  9]
# [[  5.73785042  -0.24309076  -7.26199   ]
#  [ 11.88064588  -1.28331873 -10.80707276]
#  [ 10.72104906  -1.4814617  -15.29795313]]
# final construct vals:  [tensor([[28.0156]], requires_grad=True), tensor([[28.1689]], requires_grad=True)]
# 2 [32  8]
# [[  5.71131848  -0.24804274  -7.26057725]
#  [ 11.92685322  -1.28565598 -10.80396916]
#  [ 10.73268958  -1.4907173  -15.30081674]]
# final construct vals:  [tensor([[28.0126]], requires_grad=True), tensor([[28.1811]], requires_grad=True)]
# 3 [33  7]
# [[  5.70420977  -0.24988919  -7.26091991]
#  [ 11.94689726  -1.28888075 -10.80609463]
#  [ 10.74884427  -1.49649127 -15.30541508]]
# final construct vals:  [tensor([[28.0123]], requires_grad=True), tensor([[28.1953]], requires_grad=True)]
# 4 [34  6]
# [[  5.67405584  -0.24799162  -7.25847886]
#  [ 11.90996746  -1.30032065 -10.80535364]
#  [ 10.74520847  -1.48401915 -15.29744135]]
# final construct vals:  [tensor([[28.0217]], requires_grad=True), tensor([[28.1753]], requires_grad=True)]
# 5 [35  5]
# [[  5.63425668  -0.23878842  -7.25142948]
#  [ 11.88189484  -1.33120008 -10.80228314]
#  [ 10.66911501  -1.4503867  -15.26676317]]
# final construct vals:  [tensor([[28.0469]], requires_grad=True), tensor([[28.0707]], requires_grad=True)]
# 6 [36  4]
# [[  5.63490183  -0.22742997  -7.25141021]
#  [ 12.05969529  -1.35423941 -10.84973387]
#  [ 10.5556476   -1.4198699  -15.23612957]]
# final construct vals:  [tensor([[28.0708]], requires_grad=True), tensor([[27.9050]], requires_grad=True)]
# 7 [37  3]
# [[  5.64547771  -0.22872671  -7.25811933]
#  [ 12.07309611  -1.35454961 -10.89462119]
#  [ 10.58369317  -1.41771817 -15.24551399]]
# final construct vals:  [tensor([[28.0664]], requires_grad=True), tensor([[27.8636]], requires_grad=True)]
# 8 [38  2]
# [[  5.6135623   -0.24137281  -7.23842933]
#  [ 11.76888077  -1.36748509 -10.58168449]
#  [ 10.67913225  -1.45895774 -15.26513037]]
# final construct vals:  [tensor([[28.0392]], requires_grad=True), tensor([[28.2769]], requires_grad=True)]
# 9 [39  1]
# [[  5.60317645  -0.23712992  -7.22925051]
#  [ 11.74174317  -1.0538193  -10.17474746]
#  [ 10.67949441  -1.43396527 -15.26383081]]
# final construct vals:  [tensor([[28.0339]], requires_grad=True), tensor([[29.1079]], requires_grad=True)]
# 10 [40  0]
# [[  5.63660227  -0.23592376  -7.25203296]
#  [ 11.89597505  -1.33643664 -10.80662013]
#  [ 10.64976481  -1.44252791 -15.26615599]]
# final construct vals:  [tensor([[28.0521]], requires_grad=True), tensor([[29.1079]], requires_grad=True)]
# [ -8.15735525  -7.36832922  -8.0914845   -8.09698201  -8.08856821
#   -8.15558446  -8.0643735   -8.00773954  -8.01891789  -8.03534173
#  -19.30604924]
# time_constant_param_ls [tensor([9.8708], requires_grad=True), tensor([2.6522], requires_grad=True)]
# No change point!
# Batch 32
# [tensor([9.8708]), tensor([2.6522])]
# 28.0
# Final kernel size:  40
# Temperature:  tensor([[1.0000, 0.6791, 1.0000],
#         [1.0000, 0.6071, 1.0000],
#         [1.0000, 0.3344, 1.0000]])
# new_construct_vals:  [tensor([[28.0521]], requires_grad=True), tensor([[28.0521]], requires_grad=True)]
# tmp_occurence_times:  [30 10]
# 0 [30 10]
# [[  6.88514526  -6.00367944  -8.60960425]
#  [ 13.16912119  -4.1240945  -12.79517031]
#  [ 11.14919396  -2.10693606 -15.77903516]]
# final construct vals:  [tensor([[28.0075]], requires_grad=True), tensor([[28.1955]], requires_grad=True)]
# 1 [31  9]
# [[  5.71719575  -0.38624414  -7.57101048]
#  [ 13.20012275  -1.13648694 -12.34164   ]
#  [ 11.24999022  -1.52578242 -15.57510099]]
# final construct vals:  [tensor([[28.0313]], requires_grad=True), tensor([[28.0590]], requires_grad=True)]
# 2 [32  8]
# [[  5.71568043  -0.3844322   -7.57215954]
#  [ 13.20551762  -1.13931891 -12.34306054]
#  [ 11.25044715  -1.52587292 -15.57576179]]
# final construct vals:  [tensor([[28.0331]], requires_grad=True), tensor([[28.0585]], requires_grad=True)]
# 3 [33  7]
# [[  5.69506003  -0.38009444  -7.57268481]
#  [ 13.23766055  -1.14738378 -12.34385013]
#  [ 11.23297283  -1.52067646 -15.57270577]]
# final construct vals:  [tensor([[28.0441]], requires_grad=True), tensor([[28.0274]], requires_grad=True)]
# 4 [34  6]
# [[  5.66968083  -0.36616888  -7.57819171]
#  [ 13.43831563  -1.16386718 -12.35743066]
#  [ 11.15101617  -1.50892826 -15.56694265]]
# final construct vals:  [tensor([[28.0708]], requires_grad=True), tensor([[27.9313]], requires_grad=True)]
# 5 [35  5]
# [[  5.67580614  -0.34875021  -7.59523307]
#  [ 13.86967822  -1.16182221 -12.4347972 ]
#  [ 11.04033058  -1.49421019 -15.57591062]]
# final construct vals:  [tensor([[28.0955]], requires_grad=True), tensor([[27.7884]], requires_grad=True)]
# 6 [36  4]
# [[  5.69923806  -0.34783083  -7.61187543]
#  [ 13.9632629   -1.14391311 -12.5452614 ]
#  [ 11.0767051   -1.48220637 -15.60329287]]
# final construct vals:  [tensor([[28.0903]], requires_grad=True), tensor([[27.7131]], requires_grad=True)]
# 7 [37  3]
# [[  5.71012276  -0.36264438  -7.61160431]
#  [ 13.64983705  -1.13671617 -12.56110776]
#  [ 11.19066713  -1.50951897 -15.61182106]]
# final construct vals:  [tensor([[28.0632]], requires_grad=True), tensor([[27.7757]], requires_grad=True)]
# 8 [38  2]
# [[  5.69983039  -0.38267726  -7.56880661]
#  [ 13.1875721   -1.1499719  -12.30835084]
#  [ 11.24267346  -1.52077974 -15.57046719]]
# final construct vals:  [tensor([[28.0380]], requires_grad=True), tensor([[28.0703]], requires_grad=True)]
# 9 [39  1]
# [[  5.69745666  -0.37758058  -7.54750457]
#  [ 12.94035565  -1.03982795 -11.96132115]
#  [ 11.25138207  -1.50786257 -15.53949551]]
# final construct vals:  [tensor([[28.0317]], requires_grad=True), tensor([[28.7848]], requires_grad=True)]
# 10 [40  0]
# [[  5.70846059  -0.37966208  -7.5722646 ]
#  [ 13.21026827  -1.14206992 -12.34333206]
#  [ 11.24001195  -1.52061001 -15.57379328]]
# final construct vals:  [tensor([[28.0413]], requires_grad=True), tensor([[28.7848]], requires_grad=True)]
# [ -8.37299114  -8.08439793  -8.37097759  -8.24278571  -7.99517395
#   -8.02490856  -8.28251672  -8.37170198  -8.36896069  -8.36895624
#  -18.2150593 ]
# time_constant_param_ls [tensor([9.8707], requires_grad=True), tensor([2.6523], requires_grad=True)]
# No change point!
# Batch 33
# [tensor([9.8707]), tensor([2.6523])]
# 28.0
# Final kernel size:  40
# Temperature:  tensor([[1.0000, 0.6529, 1.0000],
#         [1.0000, 0.6174, 1.0000],
#         [1.0000, 0.3401, 1.0000]])
# new_construct_vals:  [tensor([[28.0413]], requires_grad=True), tensor([[28.0413]], requires_grad=True)]
# tmp_occurence_times:  [30 10]
# 0 [30 10]
# [[  6.7035478   -6.12081193  -9.3822293 ]
#  [ 15.3894936   -3.18635393 -12.57318373]
#  [ 11.20402585  -2.18491775 -16.21196311]]
# final construct vals:  [tensor([[27.9720]], requires_grad=True), tensor([[28.0429]], requires_grad=True)]
# 1 [31  9]
# [[  5.30344291  -0.41589433  -8.24485783]
#  [ 16.20843008  -1.19609087 -12.35893475]
#  [ 11.138995    -1.56998779 -15.89792627]]
# final construct vals:  [tensor([[27.9703]], requires_grad=True), tensor([[27.8967]], requires_grad=True)]
# 2 [32  8]
# [[  5.29628798  -0.40336865  -8.24699106]
#  [ 16.2670851   -1.19045177 -12.36087373]
#  [ 11.13370023  -1.56342431 -15.89954696]]
# final construct vals:  [tensor([[27.9850]], requires_grad=True), tensor([[27.8584]], requires_grad=True)]
# 3 [33  7]
# [[  5.30629268  -0.37502804  -8.25805978]
#  [ 16.55111151  -1.17718804 -12.38406944]
#  [ 11.09076452  -1.55222916 -15.9076485 ]]
# final construct vals:  [tensor([[28.0160]], requires_grad=True), tensor([[27.7654]], requires_grad=True)]
# 4 [34  6]
# [[  5.34769484  -0.34075556  -8.28424527]
#  [ 17.09557096  -1.13536378 -12.47932552]
#  [ 11.02747012  -1.52523172 -15.93872789]]
# final construct vals:  [tensor([[28.0444]], requires_grad=True), tensor([[27.6320]], requires_grad=True)]
# 5 [35  5]
# [[  5.38648468  -0.32962709  -8.31505375]
#  [ 17.3128331   -1.09395725 -12.62093744]
#  [ 11.07515301  -1.49431329 -15.98425227]]
# final construct vals:  [tensor([[28.0420]], requires_grad=True), tensor([[27.5322]], requires_grad=True)]
# 6 [36  4]
# [[  5.4029616   -0.34346841  -8.33854766]
#  [ 17.16166148  -1.06959085 -12.76494303]
#  [ 11.18169433  -1.51009764 -16.02641649]]
# final construct vals:  [tensor([[28.0154]], requires_grad=True), tensor([[27.4867]], requires_grad=True)]
# 7 [37  3]
# [[  5.38890139  -0.37127007  -8.34430122]
#  [ 16.99909802  -1.0840877  -12.84601379]
#  [ 11.21069243  -1.56258884 -16.02640341]]
# final construct vals:  [tensor([[27.9848]], requires_grad=True), tensor([[27.4658]], requires_grad=True)]
# 8 [38  2]
# [[  5.34998923  -0.41961125  -8.30159557]
#  [ 16.64293631  -1.17023632 -12.67508885]
#  [ 11.16902091  -1.59902526 -15.96237285]]
# final construct vals:  [tensor([[27.9574]], requires_grad=True), tensor([[27.5167]], requires_grad=True)]
# 9 [39  1]
# [[  5.33149161  -0.43123514  -8.25112838]
#  [ 16.23535521  -1.20268337 -12.3968232 ]
#  [ 11.12207329  -1.57604418 -15.90771821]]
# final construct vals:  [tensor([[27.9456]], requires_grad=True), tensor([[27.7640]], requires_grad=True)]
# 10 [40  0]
# [[  5.33154484  -0.42979518  -8.2431401 ]
#  [ 16.17689631  -1.19529811 -12.3559391 ]
#  [ 11.11590446  -1.57370084 -15.89674819]]
# final construct vals:  [tensor([[27.9460]], requires_grad=True), tensor([[27.7640]], requires_grad=True)]
# [ -7.07027591  -7.07671238  -6.96598365  -6.6359732   -6.30674666
#   -6.0636703   -6.23291383  -6.70605424  -6.96758318  -7.03282385
#  -16.36239251]
# time_constant_param_ls [tensor([9.8706], requires_grad=True), tensor([2.6524], requires_grad=True)]
# No change point!
# Batch 34
# [tensor([9.8706]), tensor([2.6524])]
# 28.0
# Final kernel size:  40
# Temperature:  tensor([[1.0000, 0.6178, 1.0000],
#         [1.0000, 0.6703, 1.0000],
#         [1.0000, 0.3693, 1.0000]])
# new_construct_vals:  [tensor([[27.9460]], requires_grad=True), tensor([[27.9460]], requires_grad=True)]
# tmp_occurence_times:  [30 10]
# 0 [30 10]
# [[  6.01270474  -6.53719316 -10.02876461]
#  [ 15.78774095  -2.96621349 -11.64744436]
#  [ 10.40243241  -2.06380063 -15.26979679]]
# final construct vals:  [tensor([[28.0014]], requires_grad=True), tensor([[28.1011]], requires_grad=True)]
# 1 [31  9]

# %%
yobs
# Out:
# array([], shape=(0, 3), dtype=float64)

# %%
yobs_np[end_idx-kernel_size:end_idx]
# Out:
# array([], shape=(0, 3), dtype=float64)

# %%
kernel_size
# Out:
# 50

# %%
[torch.tensor([[17.]], requires_grad=True)]
# Out:
# [tensor([[17.]], requires_grad=True)]

# %%
new_theta[-1].item()
# Out:
# 16.71255231878896

# %%
np.arange(0., 5, 1)
# Out:
# array([0., 1., 2., 3., 4.])
